# %%
import os
import gzip
import json
import pprint
from collections import defaultdict
from tqdm import tqdm

# %%
print(os.listdir("./download_train"))
train_files = [os.path.join("./download_train", file) for file in os.listdir("./download_train")] 
train_files
# Out:
# ['SearchQA.jsonl.gz', 'NewsQA.jsonl.gz', 'TriviaQA.jsonl.gz', 'NaturalQuestions.jsonl.gz', 'SQuAD.jsonl.gz', 'HotpotQA.jsonl']
# ['./download_train/SearchQA.jsonl.gz',
#  './download_train/NewsQA.jsonl.gz',
#  './download_train/TriviaQA.jsonl.gz',
#  './download_train/NaturalQuestions.jsonl.gz',
#  './download_train/SQuAD.jsonl.gz',
#  './download_train/HotpotQA.jsonl']

# %%
print(os.listdir("./download_in_domain_dev"))
in_domain_dev_files = [os.path.join("./download_in_domain_dev", file) for file in os.listdir("./download_in_domain_dev")] 
in_domain_dev_files
# Out:
# ['SearchQA.jsonl.gz', 'NewsQA.jsonl.gz', 'TriviaQA.jsonl.gz', 'NaturalQuestions.jsonl.gz', 'HotpotQA.jsonl.gz', 'SQuAD.jsonl.gz']
# ['./download_in_domain_dev/SearchQA.jsonl.gz',
#  './download_in_domain_dev/NewsQA.jsonl.gz',
#  './download_in_domain_dev/TriviaQA.jsonl.gz',
#  './download_in_domain_dev/NaturalQuestions.jsonl.gz',
#  './download_in_domain_dev/HotpotQA.jsonl.gz',
#  './download_in_domain_dev/SQuAD.jsonl.gz']

# %%
print(os.listdir("./download_out_of_domain_dev"))
out_domain_dev_files = [os.path.join("./download_out_of_domain_dev", file) for file in os.listdir("./download_out_of_domain_dev")] 
out_domain_dev_files
# Out:
# ['RelationExtraction.jsonl', 'RACE.jsonl.gz', 'BioASQ.jsonl.gz', 'TextbookQA.jsonl', 'DuoRC.jsonl.gz', 'DROP.jsonl.gz']
# ['./download_out_of_domain_dev/RelationExtraction.jsonl',
#  './download_out_of_domain_dev/RACE.jsonl.gz',
#  './download_out_of_domain_dev/BioASQ.jsonl.gz',
#  './download_out_of_domain_dev/TextbookQA.jsonl',
#  './download_out_of_domain_dev/DuoRC.jsonl.gz',
#  './download_out_of_domain_dev/DROP.jsonl.gz']

# %%
from bert import tokenization
tokenizer = tokenization.FullTokenizer(
     "./vocab.txt"
    ,do_lower_case = False
)

# %%
def open_file(filename) :
    if filename.split('.')[-1] == "gz" :
        file = gzip.open(filename,'rt')
    else :
        file = open(filename, 'rt')
    return file

def parse_data(filename) :
    
    num_lines = sum(1 for line in open_file(filename))
    data = open_file(filename)
    context_length = []
    query_length = []
    answer_length = []

    token_index = defaultdict(lambda: 0)
    unk_set = dict()

    for i, line in tqdm(enumerate(data), total = num_lines) :

        if i == 0 :
            continue
        
        try :
            jsondata = json.loads(line)

            context, unk_list = tokenizer.tokenize(jsondata['context'])

            for token in context :
                token_index[token] += 1
            
            for token, sub_tokens in unk_list :
                if token not in unk_set :
                    unk_set[token] = sub_tokens
            
            context_length.append(len(context))

            for _, q in enumerate(jsondata['qas']) :

                query, unk_list = tokenizer.tokenize(q['question'])

                for token in query :
                    token_index[token] += 1
                query_length.append(len(query))
                
                for token, sub_tokens in unk_list :
                    if token not in unk_set :
                        unk_set[token] = sub_tokens

                answer, _ = tokenizer.tokenize(q['answers'][0])
                answer_length.append(len(answer))

        except :
            continue

    info = {}
    info["Num. context"] = len(context_length)
    info["Num. query"] = len(query_length)
    info["Num. tokens"] = len(token_index)
    info["Avg. context length"] = sum(context_length) / len(context_length)
    info["Avg. query length"] = sum(query_length) / len(query_length)
    info["Avg. answer length"] = sum(answer_length) / len(answer_length)
    
    return token_index, info, unk_set

# %%
data = {}
for file in (train_files + out_domain_dev_files) :
    print(file)
    token_index, info, unk_set = parse_data(file)
    
    token_index_dict = dict()
    for k, v in token_index.items() :
        token_index_dict[k] = v
    
    data[file] = [token_index_dict, info, unk_set]
# Out:
# ./download_train/SearchQA.jsonl.gz
# 100%|██████████| 117385/117385 [25:59<00:00, 75.26it/s]
# ./download_train/NewsQA.jsonl.gz
# 100%|██████████| 11429/11429 [02:08<00:00, 88.77it/s]
# ./download_train/TriviaQA.jsonl.gz
# 100%|██████████| 61689/61689 [15:53<00:00, 64.68it/s]
# ./download_train/NaturalQuestions.jsonl.gz
# 100%|██████████| 104072/104072 [05:37<00:00, 308.67it/s]
# ./download_train/SQuAD.jsonl.gz
# 100%|██████████| 18886/18886 [01:13<00:00, 257.74it/s]
# ./download_train/HotpotQA.jsonl
# 100%|██████████| 72913/72913 [05:22<00:00, 246.33it/s]
#   5%|▌         | 151/2949 [00:00<00:01, 1509.21it/s]
# ./download_out_of_domain_dev/RelationExtraction.jsonl
# 100%|██████████| 2949/2949 [00:02<00:00, 1355.42it/s]
#   2%|▏         | 15/614 [00:00<00:04, 139.70it/s]
# ./download_out_of_domain_dev/RACE.jsonl.gz
# 100%|██████████| 614/614 [00:03<00:00, 172.43it/s]
#   0%|          | 0/1505 [00:00<?, ?it/s]
# ./download_out_of_domain_dev/BioASQ.jsonl.gz
# 100%|██████████| 1505/1505 [00:07<00:00, 196.83it/s]
#   0%|          | 6/1504 [00:00<00:25, 59.26it/s]
# ./download_out_of_domain_dev/TextbookQA.jsonl
# 100%|██████████| 1504/1504 [00:16<00:00, 93.54it/s]
#   4%|▍         | 9/203 [00:00<00:02, 86.44it/s]
# ./download_out_of_domain_dev/DuoRC.jsonl.gz
# 100%|██████████| 203/203 [00:02<00:00, 85.46it/s]
#   7%|▋         | 21/282 [00:00<00:01, 205.42it/s]
# ./download_out_of_domain_dev/DROP.jsonl.gz
# 100%|██████████| 282/282 [00:01<00:00, 202.18it/s]

# %%
import pickle
with open("./data.pickle", 'wb') as handle:
    pickle.dump(data, handle)

# %%
for file in (train_files + out_domain_dev_files) :
    print(file)
    pprint.pprint(data[file][1])
    try :
        unknum = data[file][0]['[UNK]']
    except :
        unknum = 0
    print("Num unique [UNK] :", len(data[file][2]))
    print("frequency  [UNK] :", unknum)
    pprint.pprint(data[file][2])
    print('')
# Out:
# ./download_train/SearchQA.jsonl.gz
# {'Avg. answer length': 2.7910277380222177,
#  'Avg. context length': 1082.8945256593743,
#  'Avg. query length': 19.140717644653446,
#  'Num. context': 117384,
#  'Num. query': 117384,
#  'Num. tokens': 26902}
# Num unique [UNK] : 1
# frequency  [UNK] : 1
# {'⅔': []}
#
# ./download_train/NewsQA.jsonl.gz
# {'Avg. answer length': 5.858926645091693,
#  'Avg. context length': 673.2030101505076,
#  'Avg. query length': 8.378087918015103,
#  'Num. context': 11428,
#  'Num. query': 74160,
#  'Num. tokens': 26372}
# Num unique [UNK] : 44
# frequency  [UNK] : 61
# {'AgÃ¼ero': ['A', '##g'],
#  'ArchipiÃ©lago': ['Arch', '##ip', '##i'],
#  'BrontÃ': ['B', '##ron', '##t'],
#  'CafÃ©': ['C', '##af'],
#  'ChloÃ©': ['Ch', '##lo'],
#  'DesafÃo': ['Des', '##af'],
#  'DreÃ¯b': ['Dr', '##e'],
#  'EnrÃquez': ['En', '##r'],
#  'EspaÃ±ol': ['E', '##sp', '##a'],
#  'FranÃ': ['Fr', '##an'],
#  'FrÃ©dÃ©ric': ['Fr'],
#  'GuantÃ': ['G', '##uant'],
#  'HermÃ¨s': ['Her', '##m'],
#  'HespÃ©rides': ['He', '##sp'],
#  'IrÃ¨ne': ['I', '##r'],
#  'JosÃ©': ['Jo', '##s'],
#  'JouÃ': ['Jo', '##u'],
#  'JÃ³zef': ['J'],
#  'KhloÃ©': ['K', '##hl', '##o'],
#  'KÃ': ['K'],
#  'LatanÃ©': ['La', '##tan'],
#  'LimÃ³n': ['Lim'],
#  'MartÃnez': ['Mart'],
#  'NiÃ±o': ['Ni'],
#  'ParÃ©': ['Pa', '##r'],
#  'PeÃ±a': ['P', '##e'],
#  'PoirÃ©': ['Po', '##ir'],
#  'RaÃºl': ['Ra'],
#  'ThÃ©bault': ['T', '##h'],
#  'TÃ©a': ['T'],
#  'attachÃ©': ['attach'],
#  'cafÃ©': ['ca', '##f'],
#  'cafÃ©s': ['ca', '##f'],
#  'clichÃ©': ['c', '##lich'],
#  'clichÃ©s': ['c', '##lich'],
#  'consommÃ©': ['con', '##so', '##mm'],
#  'fiancÃ©': ['fi', '##an', '##c'],
#  'fiancÃ©e': ['fi', '##an', '##c'],
#  'ingÃ©nue': ['ing'],
#  'naÃ¯ve': ['na'],
#  'rÃ©sumÃ©': ['r'],
#  'rÃ©sumÃ©s': ['r'],
#  'Ã': [],
#  'Être': []}
#
# ./download_train/TriviaQA.jsonl.gz
# {'Avg. answer length': 3.2401277395927894,
#  'Avg. context length': 998.746060822202,
#  'Avg. query length': 17.76444365192582,
#  'Num. context': 61688,
#  'Num. query': 61688,
#  'Num. tokens': 28270}
# Num unique [UNK] : 7239
# frequency  [UNK] : 20170
# {'0Y4wɚx': ['0', '##Y', '##4', '##w'],
#  '0˚': ['0'],
#  '100ハララがあり': ['100', '##ハ', '##ラ', '##ラ'],
#  '100만': ['100'],
#  '105mであり': ['105', '##m'],
#  '10AÃ¸C': ['10', '##A'],
#  '10Ă10': ['10'],
#  '10┬ápm': ['10'],
#  '113пїЅ': ['113', '##п', '##ї'],
#  '118ヶ': ['118'],
#  '121℃': ['121'],
#  '125mのアファール': ['125', '##m', '##の', '##ア', '##フ'],
#  '126˚F': ['126'],
#  '1482пїЅ1486': ['148', '##2', '##п', '##ї'],
#  '1503пїЅ1506': ['150', '##3', '##п', '##ї'],
#  '15Ð': ['15'],
#  '1760â€™s': ['1760', '##â', '##€'],
#  '1780â€™s': ['1780', '##â', '##€'],
#  '1799↓': ['1799'],
#  '17일': ['17'],
#  '180˚': ['180'],
#  '1870пїЅ1871': ['1870', '##п', '##ї'],
#  '1880â€™s': ['1880', '##â', '##€'],
#  '1890â€™s': ['1890', '##â', '##€'],
#  '18˚30': ['18'],
#  '18пїЅC': ['18', '##п', '##ї'],
#  '1900â€™s': ['1900', '##â', '##€'],
#  '191ÃÂ': ['191'],
#  '1964►': ['1964'],
#  '1974Ã¢â': ['1974'],
#  '1995пїЅ96': ['1995', '##п', '##ї'],
#  '1996►': ['1996'],
#  '1998™': ['1998'],
#  '19â€™Th': ['19', '##â', '##€'],
#  '19˚': ['19'],
#  '1mm∼150mm': ['1', '##mm'],
#  '1Ã': ['1'],
#  '1ďż˝C': ['1', '##ď', '##ż'],
#  '1пїЅC': ['1', '##п', '##ї'],
#  '1™': ['1'],
#  '1ドル＝3': ['1', '##ド', '##ル'],
#  '1ペニーも': ['1'],
#  '1リヤールは100ハララ': ['1', '##リ'],
#  '2008™': ['2008'],
#  '2008►': ['2008'],
#  '2011년': ['2011'],
#  '20ďż˝C': ['20', '##ď', '##ż'],
#  '20˚C': ['20'],
#  '20リヤール': ['20', '##リ'],
#  '214mのガリラヤ': ['214', '##m', '##の', '##ガ', '##リ', '##ラ'],
#  '22℃': ['22'],
#  '24˚C': ['24'],
#  '2555mであり': ['255', '##5', '##m'],
#  '27˚S': ['27'],
#  '2DS™': ['2D', '##S'],
#  '2Ã': ['2'],
#  '2ÃÂ': ['2'],
#  '2˄': ['2'],
#  '2пїЅ': ['2', '##п', '##ї'],
#  '2пїЅC': ['2', '##п', '##ї'],
#  '300주년': ['300'],
#  '32пїЅ': ['32', '##п', '##ї'],
#  '337℃': ['33', '##7'],
#  '36пїЅC': ['36', '##п', '##ї'],
#  '3DS™': ['3D', '##S'],
#  '3D™': ['3D'],
#  '3ďż˝C': ['3', '##ď', '##ż'],
#  '40˚C': ['40'],
#  '40˚F': ['40'],
#  '40℃': ['40'],
#  '45˚': ['45'],
#  '45пїЅ': ['45', '##п', '##ї'],
#  '4AÃ¸': ['4', '##A'],
#  '4Ã¨': ['4'],
#  '4˄': ['4'],
#  '4пїЅC': ['4', '##п', '##ї'],
#  '4ߓ': ['4'],
#  '500がそれぞれ': ['500'],
#  '52˚C': ['52'],
#  '55Ãâ€šÃ': ['55'],
#  '5KI͖f': ['5', '##K', '##I'],
#  '5™': ['5'],
#  '5⅝': ['5'],
#  '5종': ['5'],
#  '61Ãâ€šÃ': ['61'],
#  '64™': ['64'],
#  '6пїЅ': ['6', '##п', '##ї'],
#  '6пїЅC': ['6', '##п', '##ї'],
#  '6℉': ['6'],
#  '6™': ['6'],
#  '6월': ['6'],
#  '72mのグアリーチョ': ['72', '##m', '##の', '##グ', '##ア', '##リ', '##ー'],
#  '75˚F': ['75'],
#  '75リヤルである': ['75', '##リ'],
#  '7пїЅC': ['7', '##п', '##ї'],
#  '83℃': ['83'],
#  '86mのデスヴァレー': ['86', '##m', '##の', '##デ', '##ス'],
#  '8kßiG4oխg': ['8', '##k', '##ß', '##i', '##G', '##4', '##o'],
#  '90ÃâÃÂ°': ['90'],
#  '90â€™s': ['90', '##â', '##€'],
#  '970d3eĔ': ['97', '##0', '##d', '##3', '##e'],
#  '9пїЅC': ['9', '##п', '##ї'],
#  'Advance™': ['Advance'],
#  'AirportDÃ¼sseldorf': ['Airport', '##D'],
#  'Alley✓': ['Alley'],
#  'AlmodÃ³var': ['Al', '##mo', '##d'],
#  'Alĭ': ['Al'],
#  'Americanâ€™s': ['American', '##â', '##€'],
#  'Americaâ€™s': ['America', '##â', '##€'],
#  'Amhrรกn': ['Am', '##hr', '##ร'],
#  'Anatolḗ': ['Ana', '##to', '##l'],
#  'Android™': ['Android'],
#  'AndrÃ©': ['And', '##r'],
#  'AndrÃ©s': ['And', '##r'],
#  'Angelottiｿｽfs': ['Angelo', '##tti'],
#  'AngoulÃªme': ['Ang', '##ou', '##l'],
#  'Apeďż˝tif': ['A', '##pe', '##ď', '##ż'],
#  'Appleâ¦celebs': ['Apple', '##â'],
#  'Apron™': ['Apr', '##on'],
#  'ArchipiÃ©lago': ['Arch', '##ip', '##i'],
#  'Argentina™': ['Argentina'],
#  'AriÃ¨ge': ['Ari'],
#  'Arts™': ['Arts'],
#  'AubignÃ©': ['Au', '##bi', '##gn'],
#  'AustralianпїЅs': ['Australian', '##п', '##ї'],
#  'AustraliaпїЅs': ['Australia', '##п', '##ї'],
#  'AvalosпїЅwho': ['Ava', '##los', '##п', '##ї'],
#  'AÃ±adir': ['A'],
#  'Aâ¦': ['A', '##â'],
#  'A∆PIA': ['A'],
#  'BOËN': ['B', '##O'],
#  'BRÛLÉ': ['BR'],
#  'BarbÃ³n': ['Bar', '##b'],
#  'Bayḑā': ['Bay'],
#  'BeamÃ': ['Be', '##am'],
#  'Beauty™': ['Beauty'],
#  'BedÃ¸ich': ['Bed'],
#  'BedÅ™ich': ['Bed', '##Å'],
#  'BenefitsPal™': ['Ben', '##ef', '##its', '##P', '##al'],
#  'Benzâ€™s': ['Benz', '##â', '##€'],
#  'BertramÊs': ['Bert', '##ram'],
#  'Bettie☯': ['Bet', '##tie'],
#  'Bhelg̑h': ['B', '##hel', '##g'],
#  'Bing™': ['Bing'],
#  'Bite™': ['Bit', '##e'],
#  'Bith™': ['Bit', '##h'],
#  'Bizetｿｽfs': ['B', '##ize', '##t'],
#  'BjĂ¸rk': ['B', '##j'],
#  'BlaskÃ³': ['B', '##las', '##k'],
#  'BlÃ¼cher': ['B', '##l'],
#  'Bohemeｿｽf': ['Bo', '##hem', '##e'],
#  'Bohemeｿｽh': ['Bo', '##hem', '##e'],
#  'Bookkeeper™': ['Book', '##keeper'],
#  'BorsaÊÄ': ['Bo', '##rsa'],
#  'Box™': ['Box'],
#  'Box™²': ['Box'],
#  'Boy™': ['Boy'],
#  'Brazil™': ['Brazil'],
#  'Bridge↓': ['Bridge'],
#  'Britaina™s': ['Britain', '##a'],
#  'BritainпїЅ': ['Britain', '##п', '##ї'],
#  'BrochÃ©': ['B', '##ro', '##ch'],
#  'BrontÃ': ['B', '##ron', '##t'],
#  'Brontﾃｫ': ['B', '##ron', '##t'],
#  'Bruceâ€™s': ['Bruce', '##â', '##€'],
#  'BrulÃ©': ['B', '##ru', '##l'],
#  'Butterworthâ€™s': ['But', '##ter', '##worth', '##â', '##€'],
#  'BÃ¦rum': ['B'],
#  'BÃ©la': ['B'],
#  'Bàmakɔ̌': ['B', '##à', '##ma', '##k', '##ɔ'],
#  'CENTRE™': ['CE', '##NT', '##RE'],
#  'CHOSŎN': ['CH', '##OS'],
#  'CIGÙRI': ['C', '##IG'],
#  'CITROËN': ['C', '##IT', '##RO'],
#  'CafÃ©': ['C', '##af'],
#  'CafĂ': ['C', '##af'],
#  'Cantina™': ['Can', '##tina'],
#  'CantÃ£o': ['Can', '##t'],
#  'Care™': ['Care'],
#  'Care™Ask': ['Care'],
#  'Carisle▬▬★☆★■': ['Car', '##is', '##le'],
#  'Carmenâ€™s': ['Carmen', '##â', '##€'],
#  'Carmenｿｽfs': ['Carmen'],
#  'Carry™': ['Carr', '##y'],
#  'Carȇme': ['Car'],
#  'Cask™': ['C', '##ask'],
#  'Cavaradossiｿｽfs': ['C', '##ava', '##rado', '##ssi'],
#  'CaÃ±a': ['C', '##a'],
#  'Center™': ['Center'],
#  'Center™Buy': ['Center'],
#  'CereCalase™': ['Ce', '##re', '##C', '##ala', '##se'],
#  'ChancesR™': ['Chance', '##s', '##R'],
#  'Chandlerâ€™s': ['Chandler', '##â', '##€'],
#  'Charger™': ['Charge', '##r'],
#  'ChristieÊs': ['Christie'],
#  'Chrome™': ['Ch', '##rome'],
#  'ChÃ': ['Ch'],
#  'ChÃ¢lus': ['Ch'],
#  'CiarÃ': ['C', '##iar'],
#  'Cinetic™': ['C', '##inet', '##ic'],
#  'CitÃ©': ['C', '##it'],
#  'Clarkeâ¦': ['Clarke', '##â'],
#  'ColÃ³n': ['Col'],
#  'Comments↓Stirling': ['Co', '##mme', '##nts'],
#  'Company™': ['Company'],
#  'CompiÃ¨gne': ['Co', '##mp', '##i'],
#  'ComposersBedÅ™ich': ['Composer', '##s', '##B', '##ed', '##Å'],
#  'ComÃºn': ['Co', '##m'],
#  'ConfÃ©rence': ['Con', '##f'],
#  'CongrĂ¨s': ['Con', '##g', '##r'],
#  'Conqueror⎯as': ['Con', '##quer', '##or'],
#  'Corner™': ['Corner'],
#  'Council\u0871': ['Council'],
#  'Country↓': ['Country'],
#  'CoxBox™': ['Cox', '##B', '##ox'],
#  'CoxÕs': ['Cox'],
#  'CoĂŻdĂŠ': ['Co'],
#  'CrackÊd': ['C', '##rack'],
#  'CritÃ©rium': ['C', '##rit'],
#  'Crock™': ['C', '##rock'],
#  'CrĂ¨me': ['C', '##r'],
#  'CunÃ©gonde': ['C', '##un'],
#  'Cup™': ['Cup'],
#  'Cup™FIFA': ['Cup'],
#  'CuraÃ': ['C', '##ura'],
#  'Cutians™': ['Cut', '##ians'],
#  'CÃ¦sar': ['C'],
#  'CÐ°ÑÐ¾ÐºÐ°': ['C'],
#  'CÑÑÐ°': ['C', '##Ñ', '##Ñ'],
#  'CÔTE': ['C'],
#  'C♮': ['C'],
#  'DSi™': ['DS', '##i'],
#  'DS™': ['DS'],
#  'DVOŘÁK': ['D', '##VO'],
#  'DaisyвЂ™s': ['Daisy', '##в'],
#  'DalÃâ': ['Dal'],
#  'Damage↓': ['Dam', '##age'],
#  'Date↓': ['Date'],
#  'DauphinÃ©': ['Da', '##up', '##hin'],
#  'Decoder™': ['Dec', '##ode', '##r'],
#  'Decoder™East': ['Dec', '##ode', '##r'],
#  'Dehḵodā': ['De', '##h'],
#  'DellÃ¢ordine': ['Dell'],
#  'Deqlaṯ': ['De', '##q', '##la'],
#  'DescripciÃ³n': ['Des', '##c', '##rip', '##ci'],
#  'DescÃ': ['Des', '##c'],
#  'DianaпїЅ': ['Diana', '##п', '##ї'],
#  'Diathḗkē': ['Di', '##ath'],
#  'DidnÊt': ['Didn'],
#  'Dionȳsus': ['Dion'],
#  'DisponibilitÃ': ['Di', '##sp', '##oni', '##bil', '##it'],
#  'District\u0871': ['District'],
#  'Docet™': ['Doc', '##et'],
#  'Donizettiｿｽfs': ['Don', '##ize', '##tti'],
#  'Döpp': ['Do'],
#  'DuPont™': ['Du', '##P', '##ont'],
#  'Dulcamaraｿｽfs': ['Du', '##l', '##cam', '##ara'],
#  'DÃa': ['D'],
#  'DÃ¼sseldorf': ['D'],
#  'Délįne': ['D', '##é', '##l'],
#  'Dëẁëlëss': ['D', '##ë'],
#  'Dāmoklē̂s': ['D', '##ā', '##mo', '##k', '##l', '##ē'],
#  'DẪN': ['D'],
#  'D♮': ['D'],
#  'EMINƎM': ['EMI', '##N'],
#  'ENGLISHPORTUGUÊS': ['E',
#                       '##NG',
#                       '##L',
#                       '##IS',
#                       '##HP',
#                       '##OR',
#                       '##TU',
#                       '##G',
#                       '##U'],
#  'EarthοΏ½s': ['Earth', '##ο'],
#  'Egg™': ['Egg'],
#  'EncyclopÃ¦dia': ['En', '##cy', '##c', '##lop'],
#  'England⎯who': ['England'],
#  'Engliſh': ['En', '##gli'],
#  'Ereẓ': ['E', '##re'],
#  'EspaÃ±a': ['E', '##sp', '##a'],
#  'EspaÃ±aâ': ['E', '##sp', '##a'],
#  'EspaÃ±ol': ['E', '##sp', '##a'],
#  'EsquivelвЂ™s': ['E', '##s', '##qui', '##vel', '##в'],
#  'EstÃ': ['E', '##st'],
#  'EstÃ©e': ['E', '##st'],
#  'EstĂŠvez': ['E', '##st'],
#  'Euclidâ€™s': ['E', '##uc', '##lid', '##â', '##€'],
#  'EugÃ¨ne': ['E', '##ug'],
#  'EugÃ©nie': ['E', '##ug'],
#  'Eurostar™': ['Euro', '##star'],
#  'Evacuated\u0871': ['Eva', '##cu', '##ated'],
#  'Everest⎯': ['Everest'],
#  'Everglades❞': ['Ever', '##g', '##lades'],
#  'Exploit™': ['Ex', '##p', '##lo', '##it'],
#  'Extensions™': ['Extension', '##s'],
#  'FAXｿｽF': ['FA', '##X'],
#  'FanX™': ['Fan', '##X'],
#  'Fatherâ€™s': ['Father', '##â', '##€'],
#  'FawkesпїЅ': ['F', '##aw', '##kes', '##п', '##ї'],
#  'FerrÃ©s': ['Fe', '##rr'],
#  'Festival™': ['Festival'],
#  'FieldsпїЅ': ['Fields', '##п', '##ї'],
#  'FitzgeraldвЂ™s': ['Fitzgerald', '##в'],
#  'Fi™': ['Fi'],
#  'Flagsâ€™': ['Flags', '##â', '##€'],
#  'Flagâ€™s': ['Flag', '##â', '##€'],
#  'Flambďż˝e': ['F', '##lam', '##b', '##ď', '##ż'],
#  'FranceFranÃ': ['France', '##F', '##ran'],
#  'Française': ['Fr', '##an', '##c'],
#  'Franklinâ€™s': ['Franklin', '##â', '##€'],
#  'FranÃ': ['Fr', '##an'],
#  'FranÃÂ': ['Fr', '##an'],
#  'FreischÃ¼tz': ['Fr', '##ei', '##sch'],
#  'FrontiÃ¨res': ['Front', '##i'],
#  'FrÃ': ['Fr'],
#  'FrÃ©dÃ©ric': ['Fr'],
#  'Future™': ['Future'],
#  'FÃlmico': ['F'],
#  'FÃ¼hrer': ['F'],
#  'FÃ¼r': ['F'],
#  'FŁĂŴï': ['F', '##Ł'],
#  'F럅럕ation': ['F'],
#  'GH₵': ['G', '##H'],
#  'Gahnawiyoˀgeh': ['G', '##ahn', '##aw', '##i', '##yo'],
#  'GalÃ': ['G', '##al'],
#  'GameCube™': ['Game', '##C', '##ube'],
#  'Games™': ['Games'],
#  'GarcÃa': ['G', '##ar', '##c'],
#  'Garƈons': ['G', '##ar'],
#  'GatsbyвЂ™s': ['G', '##ats', '##by', '##в'],
#  'Gazetteer™': ['Gazette', '##er'],
#  'GemÃ¼tlichkeit': ['G', '##em'],
#  'Glyndŵr': ['G', '##lyn', '##d', '##w'],
#  'Gmail™': ['G', '##mail'],
#  'GoÃ': ['Go'],
#  'Göran': ['Go'],
#  'Greedo™': ['G', '##reed', '##o'],
#  'Green™': ['Green'],
#  'GuantÃ': ['G', '##uant'],
#  'GuillÃ©n': ['G', '##uil', '##l'],
#  'GulÃ': ['G', '##ul'],
#  'GuzmÃ': ['G', '##uz', '##m'],
#  'GuÌnther': ['G', '##u'],
#  'Gypsy¸': ['Gypsy'],
#  'GÃ²n': ['G'],
#  'HOME™': ['H', '##OM', '##E'],
#  'HagegÃ¥rd': ['Ha', '##ge', '##g'],
#  'HalloweÊEn': ['Hall', '##ow', '##e'],
#  'HammarskjÃ': ['Ham', '##mar', '##sk', '##j'],
#  'Hat™': ['Hat'],
#  'Haštarḵān': ['Ha', '##š', '##tar'],
#  'HelsingÃ¸r': ['He', '##ls', '##ing'],
#  'HollaÌnder': ['Ho', '##lla'],
#  'Homestead™': ['Homestead'],
#  'Home™': ['Home'],
#  'Home™Ronzoni®': ['Home'],
#  'HunterÊs': ['Hunter'],
#  'HÃ': ['H'],
#  'HÃ¥gegÃ¥rd': ['H'],
#  'HÃ¥kan': ['H'],
#  'HÃ¥ken': ['H'],
#  'HÃ©bert': ['H'],
#  'HĂ¤nsel': ['H'],
#  'IHDRZgMPLTEquτՆ֏֕ޛިީàƢ': ['I',
#                             '##HD',
#                             '##R',
#                             '##Z',
#                             '##g',
#                             '##MP',
#                             '##LT',
#                             '##E',
#                             '##q',
#                             '##u',
#                             '##τ'],
#  'IIIÃ¨me': ['III'],
#  'ITV\u0871': ['ITV'],
#  'IndianĂ': ['Indian'],
#  'Inertiaɪnˈɜr': ['In', '##ert', '##ia', '##ɪ', '##n', '##ˈ'],
#  'InglÃ©s': ['In', '##g', '##l'],
#  'Internet\u0871': ['Internet'],
#  'Introduction\u0871': ['Introduction'],
#  'IrelandпїЅ': ['Ireland', '##п', '##ї'],
#  'Isoldeｿｽfs': ['Is', '##old', '##e'],
#  'Isoldeｿｽh': ['Is', '##old', '##e'],
#  'It┬áis': ['It'],
#  'IÅÃ': ['I', '##Å'],
#  'Iâ€™m': ['I', '##â', '##€'],
#  'I̭d': ['I'],
#  'JAZZ™': ['J', '##A', '##Z', '##Z'],
#  'JTPW™': ['J', '##TP', '##W'],
#  'JTT™': ['J', '##TT'],
#  'Jack™': ['Jack'],
#  'Japanâ€™s': ['Japan', '##â', '##€'],
#  'Jas\uf8ffn': ['J', '##as'],
#  'JaÃ©n': ['J', '##a'],
#  'Joe™': ['Joe'],
#  'JoffÃ©Â': ['Jo', '##ff'],
#  'Johnâ¦': ['John', '##â'],
#  'Joseｿｽfs': ['Jose'],
#  'JosÃ¨phe': ['Jo', '##s'],
#  'Jörg': ['Jo'],
#  'Jumping™': ['Jump', '##ing'],
#  'Jürgen': ['Ju'],
#  'JÃ³n': ['J'],
#  'JÃÂ¼rgen': ['J'],
#  'KENNATΩ': ['K', '##EN', '##NA', '##T'],
#  'KRAGH\uf02a': ['K', '##RA', '##G', '##H'],
#  'Kaplanoǧlu': ['Kaplan', '##o'],
#  'Kaŝka': ['Ka'],
#  'Kenobi™': ['Ken', '##ob', '##i'],
#  'Khởi': ['K', '##h'],
#  'Kiefer▲Kathy': ['Ki', '##ef', '##er'],
#  'KingdomпїЅ': ['Kingdom', '##п', '##ї'],
#  'Kingｿｽfs': ['King'],
#  'Kitemark™': ['Kit', '##ema', '##rk'],
#  'KitzbÃ¼hel': ['Kit', '##z', '##b'],
#  'Kong™': ['Kong'],
#  'KrisztiÃ': ['Kris', '##z', '##ti'],
#  'Kr̥ṣṇa': ['K', '##r'],
#  'KÃ': ['K'],
#  'LatÃ©ral': ['La', '##t'],
#  'Learning™': ['Learning'],
#  'Lemminkäinen': ['Le', '##mm', '##ink', '##a'],
#  'LendMe™': ['Len', '##d', '##M', '##e'],
#  'Lettingweb™': ['Let', '##ting', '##we', '##b'],
#  'Leveneâ€™s': ['Lev', '##ene', '##â', '##€'],
#  'Library\u0871': ['Library'],
#  'LibÃ©rÃ©â': ['Li', '##b'],
#  'Life™': ['Life'],
#  'Location↓': ['Location'],
#  'London\uf0b7': ['London'],
#  'Loveｿｽh': ['Love'],
#  'Lundberg™': ['Lund', '##berg'],
#  'LÃ©gion': ['L'],
#  'LÃ©onard': ['L'],
#  'Lûḏîm': ['L', '##û'],
#  'Lḗthē': ['L'],
#  'MKAURORA™': ['M', '##KA', '##UR', '##OR', '##A'],
#  'Malayāḷam': ['Malay', '##ā'],
#  'Maloryâ€™s': ['Mal', '##ory', '##â', '##€'],
#  'MalvolioвЂ™s': ['Mal', '##vo', '##lio', '##в'],
#  'Manitoba\u0871': ['Manitoba'],
#  'ManÊs': ['Man'],
#  'Manāẓir': ['Man', '##ā'],
#  'Map™': ['Map'],
#  'Marcelloｿｽfs': ['Marcel', '##lo'],
#  'MarchÃ©â': ['March'],
#  'Mario™': ['Mario'],
#  'MarpleÊs': ['Mar', '##ple'],
#  'Mathematics\u0871': ['Mathematics'],
#  'MaпїЅam': ['Ma', '##п', '##ї'],
#  'McGintyÊs': ['M', '##c', '##G', '##int', '##y'],
#  'Menu☰': ['Men', '##u'],
#  'MetallicaпїЅs': ['Metal', '##lica', '##п', '##ї'],
#  'Metroid™': ['Metro', '##id'],
#  'Milẖemet': ['Mi', '##l'],
#  'Mimiｿｽfs': ['Mimi'],
#  'Minȝies': ['Min'],
#  'MontrÃ©al': ['Mont', '##r'],
#  'Morgan™': ['Morgan'],
#  'MotoGP™': ['Mo', '##to', '##GP'],
#  'Motorcycling™': ['Motor', '##cy', '##c', '##ling'],
#  'Movie™': ['Movie'],
#  'MoÃºschouri': ['Mo'],
#  'MoÌÇt': ['Mo'],
#  'Mo\ue000symypy': ['Mo'],
#  'Munḫafaḍ': ['Mu', '##n'],
#  'Museum™': ['Museum'],
#  'MusÃ©e': ['Mu', '##s'],
#  'MyLife™': ['My', '##L', '##ife'],
#  'MÃ': ['M'],
#  'MÃ¥ns': ['M'],
#  'MÃ¥nsson': ['M'],
#  'MÃ©dard': ['M'],
#  'MÃ©decins': ['M'],
#  'MÃ©riteâ': ['M'],
#  'MÃ©thode': ['M'],
#  'MÛR': ['M'],
#  'Mĕthūshelaḥ': ['M'],
#  'Mǽrsk': ['M'],
#  'M̅': ['M'],
#  'Mωϋσῆς': ['M', '##ω'],
#  'NAŢIONALĂ': ['N', '##A', '##Ţ', '##ION', '##AL'],
#  'NES™': ['NE', '##S'],
#  'NGO™': ['NGO'],
#  'NGO™On': ['NGO'],
#  'NOËL': ['NO'],
#  'Nelsona™': ['Nelson', '##a'],
#  'Nemorinoｿｽfs': ['N', '##em', '##ori', '##no'],
#  'NewsAndrÃ©s': ['News', '##A', '##nd', '##r'],
#  'NewsSaÃ¯d': ['News', '##S', '##a'],
#  'NightingaleпїЅ': ['Nightingale', '##п', '##ї'],
#  'NissanConnect™': ['Nissan', '##C', '##on', '##nect'],
#  'NiÃ¨vre': ['Ni'],
#  'NoÃ': ['No'],
#  'NÃ': ['N'],
#  'Nẵng': ['N'],
#  'OliviaвЂ™s': ['Olivia', '##в'],
#  'OpĂŠra': ['Op'],
#  'Organization\u0871': ['Organization'],
#  'OrÃ©mus': ['Or'],
#  'Ottawa\u0871': ['Ottawa'],
#  'Ottoâ€™s': ['Otto', '##â', '##€'],
#  'Oâ€™Brien': ['O', '##â', '##€'],
#  'OďŹ': ['O', '##ď'],
#  'OΠONTIΩ−N': ['O', '##Π', '##ON', '##TI'],
#  'POTËMKIN': ['P', '##OT'],
#  'Park™': ['Park'],
#  'Parliament™': ['Parliament'],
#  'Pax̌tun': ['Pa', '##x'],
#  'Pål': ['Pa'],
#  'Paṣ̌tun': ['Pa', '##ṣ'],
#  'PelĂŠ': ['P', '##el'],
#  'PenÃ©lope': ['Pen'],
#  'Peopleâ€™s': ['People', '##â', '##€'],
#  'PepÃn': ['P', '##ep'],
#  'Pep™': ['P', '##ep'],
#  'PeriÃ³dico': ['Per', '##i'],
#  'PersÃ': ['Per', '##s'],
#  'Petter™': ['Pet', '##ter'],
#  'Pet™': ['Pet'],
#  'Pet™Fun': ['Pet'],
#  'Pet™Should': ['Pet'],
#  'PhoneｿｽF': ['Phone'],
#  'Phosphorusˈfɒs': ['Ph', '##os', '##phorus', '##ˈ', '##f'],
#  'Phở': ['Ph'],
#  'Platoâ€™s': ['Plato', '##â', '##€'],
#  'Play™': ['Play'],
#  'Points™': ['Points'],
#  'PoirotÊs': ['Po', '##iro', '##t'],
#  'Pokémon™': ['Pokémon'],
#  'PorsaÊÄ': ['Po', '##rsa'],
#  'PoÃ¨tes': ['Po'],
#  'PubliÃ©': ['Pub', '##li'],
#  'Pucciniｿｽfs': ['P', '##ucci', '##ni'],
#  'Pustiĺnik': ['P', '##ust', '##i'],
#  'PÃ': ['P'],
#  'PÃ¨re': ['P'],
#  'PÃ©lissier': ['P'],
#  'PÃ©tain': ['P'],
#  'PĂşblicos': ['P'],
#  'Pˤrak': ['P'],
#  'Qassāṭỉ': ['Q', '##ass', '##ā', '##ṭ'],
#  'QuantitÃ': ['Q', '##uant', '##it'],
#  'Quia\u0871': ['Q', '##ui', '##a'],
#  'QuÃ©bec': ['Q', '##u'],
#  'RAY™': ['RA', '##Y'],
#  'RF™': ['RF'],
#  'Ragù': ['Ra', '##gu'],
#  'RamÃ³n': ['Ram'],
#  'Reason↓': ['Reason'],
#  'RebeliÃ³n': ['Rebel', '##i'],
#  'RecibirÃ': ['Re', '##ci', '##bir'],
#  'Records™': ['Records'],
#  'Red™': ['Red'],
#  'RenÃ': ['Ren'],
#  'RenÃ©': ['Ren'],
#  'RenÃ©e': ['Ren'],
#  'ReuterswÃ¤rd': ['Re', '##uters', '##w'],
#  'ReykjavÃk': ['Rey', '##k', '##ja', '##v'],
#  'ReykjavĂk': ['Rey', '##k', '##ja', '##v'],
#  'RheinÌ': ['R', '##hein'],
#  'Rhâ¦': ['R', '##h', '##â'],
#  'Richardâ€™s': ['Richard', '##â', '##€'],
#  'RincÃ³n': ['R', '##in', '##c'],
#  'Ripeness™': ['R', '##ip', '##ene', '##ss'],
#  'Rodolfoｿｽfs': ['Rod', '##ol', '##fo'],
#  'RÃ©my': ['R'],
#  'RÃºa': ['R'],
#  'Rĕmus': ['R'],
#  'Rŭ́bĭcō': ['R', '##ŭ', '##́', '##b'],
#  'SCATS™': ['SC', '##AT', '##S'],
#  'SCHOOLinSITES\u0871': ['SC',
#                          '##H',
#                          '##O',
#                          '##OL',
#                          '##in',
#                          '##SI',
#                          '##TE',
#                          '##S'],
#  'STARmeter▲': ['ST', '##AR', '##meter'],
#  'SUBTÍTULOS◀▪▪▶◀▪▪▶': ['S', '##U', '##B', '##T', '##Í', '##TU', '##L', '##OS'],
#  'Sainsburyâ€™s': ['Sai', '##ns', '##bury', '##â', '##€'],
#  'SalobreÃ±a': ['Sal', '##ob', '##re'],
#  'Samorza̡d': ['Sam', '##or', '##za'],
#  'Sandtrooper™': ['Sand', '##tro', '##oper'],
#  'SaÃ¯d': ['Sa'],
#  'SaÃ´ne': ['Sa'],
#  'Sạstruga': ['Sa'],
#  'Sạstrugi': ['Sa'],
#  'Scarpiaｿｽfs': ['Sc', '##ar', '##pia'],
#  'Schweiger►Bíró': ['Sc', '##h', '##wei', '##ger'],
#  'SchÃ': ['Sc', '##h'],
#  'SeaпїЅ': ['Sea', '##п', '##ї'],
#  'Sense™': ['Sense'],
#  'Sensibility™': ['Sen', '##si', '##bility'],
#  'Series™': ['Series'],
#  'Serve™': ['Ser', '##ve'],
#  'Shlomiẗ': ['S', '##hl', '##omi'],
#  'Showplot™': ['Show', '##p', '##lot'],
#  'SigurÃ°sson': ['Si', '##gu', '##r'],
#  'Simpsons™': ['Simpsons'],
#  'Skywalker™': ['Sky', '##walk', '##er'],
#  'Sky™': ['Sky'],
#  'SmartLipo™': ['Smart', '##L', '##ip', '##o'],
#  'SocietÃ': ['So', '##cie', '##t'],
#  'Solo™': ['Solo'],
#  'Songｿｽh': ['Song'],
#  'SoufriГЁre': ['So', '##uf', '##ri', '##Г'],
#  'Spın̈al': ['S', '##p', '##ı', '##n'],
#  'Stark❄': ['Stark'],
#  'StarrÕs': ['Starr'],
#  'Statesâ¦': ['States', '##â'],
#  'StateпїЅ': ['State', '##п', '##ї'],
#  'Sternwoodâ€™s': ['Stern', '##wood', '##â', '##€'],
#  'Sticks™': ['Stick', '##s'],
#  'Stock™': ['Stock'],
#  'StraÃ¼ssler': ['St', '##ra'],
#  'StÃ©phane': ['St'],
#  'SupÃ©rieure': ['Su', '##p'],
#  'Svatoňovice': ['S', '##vat', '##on'],
#  'SwissTools™': ['Swiss', '##T', '##ool', '##s'],
#  'Sykesâ€™': ['Sykes', '##â', '##€'],
#  'System™': ['System'],
#  'SystÃ¨me': ['S', '##ys', '##t'],
#  'SÃ': ['S'],
#  'SÃ£o': ['S'],
#  'SÃ¦dÃ©n': ['S'],
#  'SÃ©rie': ['S'],
#  'SÃ¸rensdatter': ['S'],
#  'SÃ¼dtribune': ['S'],
#  'Sӭ': ['S'],
#  'TAVĘS': ['T', '##AV'],
#  'TRADUÇÃO': ['T', '##RA', '##D', '##U', '##Ç'],
#  'TRAVEL™': ['T', '##RA', '##VE', '##L'],
#  'TVSELECT™': ['TV', '##SE', '##LE', '##CT'],
#  'TV™': ['TV'],
#  'TarapacÃ': ['Tara', '##pa', '##c'],
#  'Tarḵān': ['Ta', '##r'],
#  'Technology™': ['Technology'],
#  'Test™': ['Test'],
#  'Therapy™to': ['Therapy'],
#  'TheyÕd': ['They'],
#  'ThomasпїЅs': ['Thomas', '##п', '##ї'],
#  'ThÃ©rÃ¨se': ['T', '##h'],
#  'Tjuṯa': ['T', '##ju'],
#  'Tokyoâ€™s': ['Tokyo', '##â', '##€'],
#  'TomÃ': ['Tom'],
#  'TormÃ©': ['Tor', '##m'],
#  'ToshirÃ´': ['To', '##shi', '##r'],
#  'Touch™': ['Touch'],
#  'Toâ¦': ['To', '##â'],
#  'Tristanｿｽfs': ['Tristan'],
#  'TroisiÃ¨me': ['T', '##rois', '##i'],
#  'Trẻ': ['T', '##r'],
#  'TÃ¸nsberg': ['T'],
#  'TÈatÈÃ': ['T', '##È', '##at', '##È'],
#  'Tłı̨chǫ': ['T', '##ł', '##ı'],
#  'Tŕňa': ['T'],
#  'Tȟatȟáŋka': ['T'],
#  'T̶h̶e̶': ['T'],
#  'TỪ': ['T'],
#  'Ufw҆\u0590ڜިhbKGD': ['U', '##f', '##w'],
#  'Ultrabook™': ['Ultra', '##book'],
#  'Uluṟu': ['U', '##lu'],
#  'University\u0871': ['University'],
#  'U™': ['U'],
#  'VERSION۩ஜ▬▬▬▬▬▬●': ['V', '##ER', '##SI', '##ON'],
#  'VOCÊ': ['V', '##OC'],
#  'ValerioÃ¢': ['Vale', '##rio'],
#  'ValÃ©ry': ['Val'],
#  'Valѐncia': ['Val'],
#  'Vayama™': ['V', '##aya', '##ma'],
#  'Velcro™': ['V', '##el', '##c', '##ro'],
#  'VersiÃ³n': ['V', '##ers', '##i'],
#  'VillÃ¨le': ['V', '##ill'],
#  'VoilÃ': ['V', '##oil'],
#  'VÃ': ['V'],
#  'VÃ©ronique': ['V'],
#  'V̰A': ['V'],
#  'V̰B': ['V'],
#  'V̰rel': ['V'],
#  'Wagnerｿｽfs': ['Wagner'],
#  'Wars™': ['Wars'],
#  'WarwickпїЅCastle': ['Warwick', '##п', '##ї'],
#  'Waukeshaâ€™s': ['W', '##au', '##kes', '##ha', '##â', '##€'],
#  'WerkstÃ¤tte': ['We', '##rks', '##t'],
#  'WestfÃ¤lische': ['West', '##f'],
#  'Whatâ€™s': ['What', '##â', '##€'],
#  'Wii™': ['Wii'],
#  'William⎯William': ['William'],
#  'Wind™King': ['Wind'],
#  'Winnerâ€™s': ['Winner', '##â', '##€'],
#  'Woman™': ['Woman'],
#  'Wombania™': ['W', '##omb', '##ania'],
#  'Wonâ€™t': ['Won', '##â', '##€'],
#  'Workplace™': ['Work', '##place'],
#  'Worlds\u0871': ['Worlds'],
#  'Worldâ€™s': ['World', '##â', '##€'],
#  'WorldпїЅs': ['World', '##п', '##ї'],
#  'Wrangler™': ['W', '##rang', '##ler'],
#  'Wrangler™The': ['W', '##rang', '##ler'],
#  'WtZkﹿL': ['W', '##t', '##Z', '##k'],
#  'WÃ¼rttemberg': ['W'],
#  'Wâ¦': ['W', '##â'],
#  'Wûns̄ên': ['W', '##û', '##ns'],
#  'XL™': ['X', '##L'],
#  'X̶': ['X'],
#  'Yearsâ€¦100': ['Years', '##â', '##€'],
#  'YouTubeᴴᴰ': ['YouTube'],
#  'YouTube™': ['YouTube'],
#  'YouTube⑨': ['YouTube'],
#  'YouTube◄': ['YouTube'],
#  'You™Kellogg': ['You'],
#  'Zelda™': ['Z', '##eld', '##a'],
#  'ZoÃ': ['Z', '##o'],
#  'ZŸrich': ['Z'],
#  'abĭdēn': ['a', '##b'],
#  'ademÃ': ['ad', '##em'],
#  'akˈwəvētˌ': ['a', '##k', '##ˈ', '##w', '##ə', '##v', '##ē', '##t'],
#  'almacÃ©n': ['alma', '##c'],
#  'alĭ': ['al'],
#  'amenÃ©': ['am', '##en'],
#  'amÃ©ricain': ['am'],
#  'aprÃ': ['a', '##p', '##r'],
#  'architecture⎯and': ['architecture'],
#  'arenâ€™t': ['aren', '##â', '##€'],
#  'artÃculos': ['art'],
#  'as̺katas̺una': ['as'],
#  'as∆ABC': ['as'],
#  'athlÃ¨te': ['at', '##hl'],
#  'athlÃ©tisme': ['at', '##hl'],
#  'atrÃ': ['at', '##r'],
#  'atəcɒp': ['at', '##ə', '##c'],
#  'auÃerdem': ['au'],
#  'au\u0871': ['au'],
#  'aĤ': ['a'],
#  'aɪˈæpᵻtəs': ['a', '##ɪ', '##ˈ', '##æ', '##p'],
#  'aʝaˈkutʃo': ['a'],
#  'baby⭐️': ['baby'],
#  'balʹshoye': ['b', '##al'],
#  'baɪˈɒg': ['b', '##a', '##ɪ', '##ˈ'],
#  'baˈtaʎa': ['b', '##a', '##ˈ', '##ta'],
#  'beginâ¦': ['begin', '##â'],
#  'ber΄ē': ['be', '##r'],
#  'beâ¦': ['be', '##â'],
#  'bhelg̑h': ['b', '##hel', '##g'],
#  'bil´ĭ': ['bi', '##l', '##´'],
#  'bilˌādo̅o': ['bi', '##l'],
#  'bilˌādo̅ozˈ': ['bi', '##l'],
#  'bilˌādo̅oˈ': ['bi', '##l'],
#  'biċċerija': ['bi'],
#  'blueâ¦â': ['blue', '##â'],
#  'blĕnd': ['b', '##l'],
#  'boiˈkätˌ': ['b', '##oi', '##ˈ', '##k', '##ät'],
#  'bolʾshóĭ': ['b', '##ol', '##ʾ', '##sh', '##ó'],
#  'bombâ€™s': ['bomb', '##â', '##€'],
#  'bo̅omˈər': ['b', '##o'],
#  'bo͝o': ['b', '##o'],
#  'bo͝orkh': ['b', '##o'],
#  'bo͞o': ['b', '##o'],
#  'bo͞ob': ['b', '##o'],
#  'bo͞ovā': ['b', '##o'],
#  'bridge↓': ['bridge'],
#  'brilliantâ¦': ['brilliant', '##â'],
#  'bro͞o': ['br', '##o'],
#  'brȳsan': ['br', '##y'],
#  'brĭ': ['br'],
#  'brǣc': ['br'],
#  'brɒnti': ['br'],
#  'brəˌtɔr': ['br', '##ə'],
#  'brɪˌkeɪ': ['br', '##ɪ'],
#  'brӯsan': ['br'],
#  'bulb™': ['bulb'],
#  'byo͞o': ['by', '##o'],
#  'byĭ': ['by'],
#  'byəˌlɪz': ['by', '##ə'],
#  'bÉrsaËÊÉËd': ['b', '##É', '##rsa'],
#  'bēˌyādo̅ozˈ': ['b', '##ē'],
#  'bēˌyādo̅oˈ': ['b', '##ē'],
#  'bĕ': ['b'],
#  'bĕl': ['b'],
#  'bĕn': ['b'],
#  'bĕr': ['b'],
#  'bĕrlēn': ['b'],
#  'bĭ': ['b'],
#  'bĭb': ['b'],
#  'bĭk': ['b'],
#  'bĭl': ['b'],
#  'bĭn': ['b'],
#  'bĭs': ['b'],
#  'bĭz': ['b'],
#  'bȝs': ['b'],
#  'bȝstt': ['b'],
#  'bɒn': ['b'],
#  'bəlĭsˈtĭks': ['b', '##ə', '##l'],
#  'bərˌʒin': ['b', '##ə', '##r'],
#  'bəˌli': ['b', '##ə'],
#  'bəˌtʃɔf': ['b', '##ə'],
#  'bɵˈliːjoʊ': ['b'],
#  'bʊˌlaɪ': ['b', '##ʊ'],
#  'bʊˌlɑ': ['b', '##ʊ'],
#  'bằng': ['b'],
#  'bởi': ['b'],
#  'cafÃ': ['ca', '##f'],
#  'cafÃ©': ['ca', '##f'],
#  'cafĂŠ': ['ca', '##f'],
#  'cafďż˝': ['ca', '##f', '##ď', '##ż'],
#  'canâtâ¦': ['can', '##â', '##t', '##â'],
#  'canâ€™t': ['can', '##â', '##€'],
#  'canｿｽft': ['can'],
#  'careerпїЅBush': ['career', '##п', '##ї'],
#  'caughtâ¦': ['caught', '##â'],
#  'charactersÃ¢â': ['characters'],
#  'chaÃ±ares': ['ch', '##a'],
#  'chestÃ¢âï': ['chest'],
#  'chutÃ©': ['ch', '##ut'],
#  'chänäk´kälĕ': ['ch', '##ä', '##n', '##ä', '##k', '##´', '##k', '##ä', '##l'],
#  'chēlĕrˈ': ['ch', '##ē', '##l'],
#  'chĕch': ['ch'],
#  'chĕchnyä': ['ch'],
#  'chĕchnyäˈ': ['ch'],
#  'chĕchˈnēə': ['ch'],
#  'chĕs': ['ch'],
#  'chĭ': ['ch'],
#  'chĭt': ['ch'],
#  'chōkˌwōāmāˈkä': ['ch', '##ō', '##k'],
#  'chəchĕn': ['ch', '##ə', '##ch'],
#  'chəchĕnˈ': ['ch', '##ə', '##ch'],
#  'chằng': ['ch'],
#  'chỉ': ['ch'],
#  'chỗ': ['ch'],
#  'circumcidĕre': ['c', '##ir', '##cum', '##cid'],
#  'cityâ€™s': ['city', '##â', '##€'],
#  'clichÃ©d': ['c', '##lich'],
#  'clǣg': ['c', '##l'],
#  'committeeâ€™s': ['committee', '##â', '##€'],
#  'compaÃ±ero': ['com', '##pa'],
#  'com\u0871': ['com'],
#  'com™Andrew': ['com'],
#  'confrÃ¨re': ['con', '##f', '##r'],
#  'consentirÃ': ['consent', '##ir'],
#  'conˌnubiˈality': ['con'],
#  'coriaceousˌkɔr': ['co', '##ria', '##ce', '##ous'],
#  'couldnÕt': ['couldn'],
#  'cream😉': ['cream'],
#  'crimeâ€™': ['crime', '##â', '##€'],
#  'culture⎯its': ['culture'],
#  'cÃmmel': ['c'],
#  'cÃ©lebreâ': ['c'],
#  'cÃ©lÃ¨bre': ['c'],
#  'cÃ³digo': ['c'],
#  'cædĕre': ['c', '##æ', '##d'],
#  'cȳ': ['c'],
#  'daiˈӕmitə': ['da', '##i', '##ˈ'],
#  'darlingâ¦': ['darling', '##â'],
#  'daâ¦': ['da', '##â'],
#  'daˈguerreoˌtyper': ['da', '##ˈ', '##gue', '##rre', '##o'],
#  'daˈguerreoˌtypist': ['da', '##ˈ', '##gue', '##rre', '##o'],
#  'debaird™': ['de', '##ba', '##ir', '##d'],
#  'dekm̥': ['de', '##k', '##m'],
#  'descubriÃ³': ['des', '##cu', '##bri'],
#  'dessinÃ©e': ['des', '##sin'],
#  'device™': ['device'],
#  'didnÕt': ['didn'],
#  'didnâ€™t': ['didn', '##â', '##€'],
#  'didnвЂ™t': ['didn', '##в'],
#  'dimanĉo': ['dim', '##an'],
#  'dipsomaniaˌdɪp': ['dip', '##so', '##mani', '##a'],
#  'directinâ¦': ['direct', '##in', '##â'],
#  'diÃ¨se': ['di'],
#  'diſh': ['di'],
#  'diˌfɛn': ['di'],
#  'diﬀerence': ['di'],
#  'diﬀerent': ['di'],
#  'diﬀering': ['di'],
#  'djɜ': ['d', '##j'],
#  'doesnｿｽft': ['doesn'],
#  'donâ€™t': ['don', '##â', '##€'],
#  'dorÃ©e': ['do', '##r'],
#  'do͝of': ['do'],
#  'do͝or': ['do'],
#  'do͞o': ['do'],
#  'do͞omz': ['do'],
#  'do͞oz': ['do'],
#  'drĭd': ['d', '##r'],
#  'drəˈlɒdʒ': ['d', '##r', '##ə', '##ˈ', '##l'],
#  'drɪdˌweɪt': ['d', '##r', '##ɪ', '##d'],
#  'dyo͞o': ['d', '##yo'],
#  'dyo͞o΄': ['d', '##yo'],
#  'dzĕt': ['d', '##z'],
#  'dÃas': ['d'],
#  'dÃ©couvrir': ['d'],
#  'dÃ©partement': ['d'],
#  'dÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ©cor': ['d'],
#  'dákrȳma': ['d', '##ák', '##ry'],
#  'dälo͞othē': ['d', '##ä', '##lo'],
#  'därdənĕlz´': ['d', '##ä', '##rd', '##ə', '##n'],
#  'därdənĕlzˈ': ['d', '##ä', '##rd', '##ə', '##n'],
#  'dĕ': ['d'],
#  'dĕb': ['d'],
#  'dĕd': ['d'],
#  'dĕk': ['d'],
#  'dĕl': ['d'],
#  'dĕr': ['d'],
#  'dĕs': ['d'],
#  'dĕv': ['d'],
#  'dĭ': ['d'],
#  'dĭb': ['d'],
#  'dĭks': ['d'],
#  'dĭl': ['d'],
#  'dĭp': ['d'],
#  'dĭv': ['d'],
#  'dɒgə': ['d'],
#  'dɒˈrɑːdəʊ': ['d'],
#  'dəˈɡɛrəʊˌtaɪp': ['d', '##ə', '##ˈ', '##ɡ', '##ɛ', '##r', '##ə', '##ʊ'],
#  'dəˌbist': ['d', '##ə'],
#  'dəˌsiz': ['d', '##ə'],
#  'dɛnˈdrɒl': ['d', '##ɛ', '##n', '##ˈ', '##dr'],
#  'dɛɫft': ['d', '##ɛ'],
#  'dɪˌmɪn': ['d', '##ɪ'],
#  'dɪˌsiːz': ['d', '##ɪ'],
#  'dɪ̱ʃ': ['d', '##ɪ'],
#  'dʒəˌrɪz': ['d', '##ʒ', '##ə'],
#  'dʒɪpˈsɒfɪlə': ['d', '##ʒ', '##ɪ', '##p', '##ˈ', '##s'],
#  'd̪jwo': ['d'],
#  'dҌu': ['d'],
#  'dӯr': ['d'],
#  'dỏm': ['d'],
#  'ediciÃ³n': ['ed', '##ici'],
#  'edu\u0871': ['ed', '##u'],
#  'ektomḗ': ['e', '##kt', '##om'],
#  'elementsÃ¢â': ['elements'],
#  'elēģija': ['el', '##ē'],
#  'encyklop¦di': ['en', '##cy', '##k', '##lop'],
#  'entraÃ®neur': ['en', '##tra'],
#  'envÃe': ['en', '##v'],
#  'envÃo': ['en', '##v'],
#  'envÃos': ['en', '##v'],
#  'epistemologyɪˌpɪs': ['e', '##pis', '##tem', '##ology', '##ɪ'],
#  'erfÃ¤hrt': ['er', '##f'],
#  'espadaÃ±a': ['es', '##pad', '##a'],
#  'estÃ©': ['est'],
#  'eurasiÃ': ['e', '##ura', '##si'],
#  'eus̺kaði': ['e', '##us'],
#  'ever❣': ['ever'],
#  'evˈaɲɟelos': ['e', '##v', '##ˈ', '##a', '##ɲ'],
#  'exerciseâ¦': ['exercise', '##â'],
#  'eﬀect': ['e'],
#  'eﬀort': ['e'],
#  'faiˈnӕns': ['f', '##ai', '##ˈ', '##n'],
#  'faÃ': ['f', '##a'],
#  'felesÃ©ge': ['f', '##ele', '##s'],
#  'fjʉˈnɪkjʉlər': ['f', '##j'],
#  'fleiÃig': ['fl', '##ei'],
#  'flo͝or': ['fl', '##o'],
#  'fo͝ot': ['f', '##o'],
#  'fo͞o': ['f', '##o'],
#  'française': ['f', '##ran', '##c'],
#  'friendsｿｽf': ['friends'],
#  'fruːdʒᵿvɔːr': ['f', '##ru', '##ː', '##d', '##ʒ'],
#  'frĕ': ['f', '##r'],
#  'frĕs': ['f', '##r'],
#  'frĭk': ['f', '##r'],
#  'funciÃ³n': ['fun', '##ci'],
#  'futebɔɫ': ['f', '##ute', '##b', '##ɔ'],
#  'fuˌnambuˈlation': ['f', '##u'],
#  'fyo̅onamˈbyo̅olist': ['f', '##yo'],
#  'f¸dt': ['f'],
#  'f¸r': ['f'],
#  'f¸rst': ['f'],
#  'fÃ¼hre': ['f'],
#  'fÃ¼nftÃ¤gigen': ['f'],
#  'fÃ¼r': ['f'],
#  'färo͞ok': ['f', '##ä', '##ro'],
#  'fôlˈkətĭng': ['f', '##ô', '##l', '##ˈ', '##k', '##ə', '##t'],
#  'fĕm': ['f'],
#  'fĕn': ['f'],
#  'fĕr': ['f'],
#  'fĭ': ['f'],
#  'fĭl': ['f'],
#  'fĭsh': ['f'],
#  'fĭz': ['f'],
#  'fōō´jĬmôr´ē': ['f', '##ō', '##ō', '##´', '##j'],
#  'fũˈʃaɫ': ['f', '##ũ', '##ˈ', '##ʃ', '##a'],
#  'fǣr': ['f'],
#  'fǣran': ['f'],
#  'fɒks': ['f'],
#  'fəˌmɪz': ['f', '##ə'],
#  'fəˌraɪ': ['f', '##ə'],
#  'fəˌriː': ['f', '##ə'],
#  'f℥ss': ['f'],
#  'f℥ß': ['f'],
#  'gehÃ': ['g', '##eh'],
#  'geophagydʒiˈɒf': ['g', '##eo', '##pha', '##gy', '##d', '##ʒ', '##i', '##ˈ'],
#  'giclĂŠe': ['g', '##ic', '##l'],
#  'glĕn': ['g', '##l'],
#  'glĭng': ['g', '##l'],
#  'gnṓmōn': ['g', '##n'],
#  'goesâ€¦': ['goes', '##â', '##€'],
#  'goil΄': ['go', '##il'],
#  'go͞o': ['go'],
#  'graf΄': ['g', '##ra', '##f'],
#  'great™': ['great'],
#  'groÃe': ['g', '##ro'],
#  'grĕk': ['g', '##r'],
#  'grĕsh': ['g', '##r'],
#  'gr̥ə': ['g', '##r'],
#  'gäbrēĕl': ['g', '##ä', '##b', '##r', '##ē'],
#  'gän̪d̪ʱi': ['g', '##ä', '##n'],
#  'gĕn': ['g'],
#  'gĕng': ['g'],
#  'gĭl': ['g'],
#  'gĭs': ['g'],
#  'gĭz': ['g'],
#  'gɑ͟ː': ['g', '##ɑ'],
#  'gɒl': ['g'],
#  'gɒs': ['g'],
#  'gərbʌˈʨof': ['g', '##ə', '##rb', '##ʌ', '##ˈ'],
#  'gəsˈpɒt': ['g', '##ə', '##s', '##ˈ', '##p'],
#  'gəˌfaɪl': ['g', '##ə'],
#  'gəˌnɔt': ['g', '##ə'],
#  'gɪˌtoʊ': ['g', '##ɪ'],
#  'gɪ̱ŋəm': ['g', '##ɪ'],
#  'g̑hēi': ['g'],
#  'gҨl': ['g'],
#  'habrÃa': ['ha', '##b', '##r'],
#  'habÃa': ['ha', '##b'],
#  'halkyṓn': ['ha', '##lk', '##y'],
#  'harṣate': ['ha', '##rs'],
#  'hasnｿｽft': ['hasn'],
#  'heptæ̱θlɒn': ['he', '##pt', '##æ'],
#  'herâ¦': ['her', '##â'],
#  'himâ¦': ['him', '##â'],
#  'horrĭdum': ['ho', '##rr'],
#  'hour∙cm∙°C': ['hour'],
#  'ho͝ont': ['ho'],
#  'ho͞o': ['ho'],
#  'httâ¦': ['h', '##tt', '##â'],
#  'htâ¦': ['h', '##t', '##â'],
#  'huperbolḗ': ['h', '##upe', '##rb', '##ol'],
#  'hvlmsɡ̊vʊ̯': ['h', '##v', '##lm', '##s', '##ɡ'],
#  'hwĭs': ['h', '##w'],
#  'hymḗn': ['h', '##ym'],
#  'hyperhydrosiâ¦': ['h', '##yper', '##hy', '##dr', '##os', '##i', '##â'],
#  'hôgzˈhedˌ': ['h', '##ô', '##g', '##z', '##ˈ', '##hed'],
#  'hôl΄': ['h', '##ô', '##l'],
#  'hĕb´rĬdēz': ['h'],
#  'hĕkˈyŏbə': ['h'],
#  'hĕl': ['h'],
#  'hĭp': ['h'],
#  'hōˈmōsapˈēenzˌ': ['h',
#                     '##ō',
#                     '##ˈ',
#                     '##m',
#                     '##ō',
#                     '##sa',
#                     '##p',
#                     '##ˈ',
#                     '##ē',
#                     '##en',
#                     '##z'],
#  'hǣðen': ['h'],
#  'hǣþen': ['h'],
#  'hȯrs¦pau̇': ['h'],
#  'hɑɫk': ['h', '##ɑ'],
#  'hɒd': ['h'],
#  'hɔˈrɒl': ['h', '##ɔ', '##ˈ', '##r'],
#  'hḗli': ['h'],
#  'hḗlios': ['h'],
#  'hằn': ['h'],
#  'h₂erǵ': ['h', '##₂', '##er'],
#  'h₂stḗr': ['h', '##₂', '##st'],
#  'h₂ŕ̥tḱos': ['h', '##₂'],
#  'iPhone™': ['iPhone'],
#  'ie\u0871': ['i', '##e'],
#  'if΄ə': ['if'],
#  'imÃ': ['im'],
#  'indÃ©pendant': ['in', '##d'],
#  'inflamed┬áand┬áthickened': ['in', '##f', '##lam', '##ed'],
#  'informaciÃ³n': ['inform', '##ac', '##i'],
#  'ingʹkus': ['ing'],
#  'injuries↓': ['injuries'],
#  'insuﬃcient': ['ins', '##u'],
#  'intÃ©gration': ['in', '##t'],
#  'invitÃ©s': ['in', '##vi', '##t'],
#  'inâ¦': ['in', '##â'],
#  'inˌfənītˈəm': ['in'],
#  'in┬áyour': ['in'],
#  'iphigeniaˌɪf': ['i', '##phi', '##gen', '##ia'],
#  'irvingÃ¢Â€Â™s': ['i', '##rvin', '##g'],
#  'isnｿｽft': ['isn'],
#  'its™': ['its'],
#  'itâ€™s': ['it', '##â', '##€'],
#  'it™': ['it'],
#  'iyáangẚ': ['i', '##y', '##á', '##ang'],
#  'iĭ': ['i'],
#  'iˈnɒf': ['i', '##ˈ', '##n'],
#  'iˈɒl': ['i', '##ˈ'],
#  'iˌweɪt': ['i'],
#  'iːˈnɒfɪlɪst': ['i', '##ː', '##ˈ', '##n'],
#  'jeːˈroːnimɵs': ['j', '##e', '##ː', '##ˈ', '##ro', '##ː', '##ni', '##m'],
#  'joule∙second': ['j', '##ou', '##le'],
#  'jo͞o': ['j', '##o'],
#  'juːˌtɪlɪˈtɛərɪəˌnɪzəm': ['j', '##u', '##ː'],
#  'jÃ': ['j'],
#  'jĕn': ['j'],
#  'jĕng': ['j'],
#  'jĭk': ['j'],
#  'jĭn': ['j'],
#  'jĭp': ['j'],
#  'jәn': ['j'],
#  'k7켇': ['k', '##7'],
#  'kahr´tĭ': ['ka', '##hr', '##´', '##t'],
#  'kayiṟu': ['ka', '##yi'],
#  'kaķis': ['ka'],
#  'kaķu': ['ka'],
#  'kaɪˌdɛk': ['ka', '##ɪ'],
#  'kaˈt͡ʂɨȷ̃skʲi': ['ka', '##ˈ', '##t', '##͡', '##ʂ', '##ɨ'],
#  'ke̱ʤəriː': ['k', '##e'],
#  'kiˌi': ['k', '##i'],
#  'kjʊːˈlɒts': ['k', '##j', '##ʊ', '##ː', '##ˈ', '##l'],
#  'klækˈmænənˌʃɪə': ['k',
#                     '##l',
#                     '##æ',
#                     '##k',
#                     '##ˈ',
#                     '##m',
#                     '##æ',
#                     '##n',
#                     '##ə',
#                     '##n'],
#  'klí̄nein': ['k', '##l', '##í'],
#  'klĕm': ['k', '##l'],
#  'km\uf007': ['km'],
#  'kolinskiĭ': ['k', '##olin', '##ski'],
#  'kom´ĕ': ['k', '##om', '##´'],
#  'koˑ': ['k', '##o'],
#  'ko̅o̅m': ['k', '##o'],
#  'ko͝om': ['k', '##o'],
#  'ko͝orēl': ['k', '##o'],
#  'ko͞o': ['k', '##o'],
#  'ko͞os': ['k', '##o'],
#  'kremlĭ': ['k', '##rem', '##l'],
#  'kremlĭnŭ': ['k', '##rem', '##l'],
#  'kro͞o': ['k', '##ro'],
#  'kroґsis': ['k', '##ro'],
#  'krĕm': ['k', '##r'],
#  'krĭs': ['k', '##r'],
#  'krĭsănˈthəməm': ['k', '##r'],
#  'krɪˌtud': ['k', '##r', '##ɪ'],
#  'ksuperioridad™': ['k', '##su', '##per', '##ior', '##ida', '##d'],
#  'ksuperioridad™Lost': ['k', '##su', '##per', '##ior', '##ida', '##d'],
#  'kuģakraut': ['k', '##u'],
#  'kuģī': ['k', '##u'],
#  'kuˈlɒm': ['k', '##u', '##ˈ', '##l'],
#  'kwĭn': ['k', '##w'],
#  'kwɒˈdrɪl': ['k', '##w'],
#  'kwɒˈdrɪljən': ['k', '##w'],
#  'kyo͝or': ['k', '##yo'],
#  'kyo͝orēlz': ['k', '##yo'],
#  'kyo͞o': ['k', '##yo'],
#  'kȳri': ['k', '##y'],
#  'kȳriakós': ['k', '##y'],
#  'kȳ́ri': ['k', '##y'],
#  'kàiɴzà': ['k', '##à', '##i'],
#  'kâːrlɔv̞itɕ': ['k', '##â', '##ː', '##rl', '##ɔ', '##v'],
#  'käl΄ә': ['k', '##ä', '##l'],
#  'käˌpəbläŋˈkə': ['k', '##ä'],
#  'kăr´ēăt´Ĭd': ['k', '##ă', '##r', '##´', '##ē', '##ă', '##t', '##´'],
#  'kăr´ēətĬd´': ['k', '##ă', '##r', '##´', '##ē', '##ə', '##t'],
#  'kĕnyäˈtə': ['k'],
#  'kĕr': ['k'],
#  'kĕt': ['k'],
#  'kĭ': ['k'],
#  'kĭl': ['k'],
#  'kĭn': ['k'],
#  'kĭng': ['k'],
#  'kōlĕt': ['k', '##ō', '##l'],
#  'kɑːˈtɒfɪlɪst': ['k', '##ɑ', '##ː', '##ˈ', '##t'],
#  'kɒ': ['k'],
#  'kɒləˈrï': ['k'],
#  'kɒp': ['k'],
#  'kɒziːˈʌskoʊ': ['k'],
#  'kɒˈkeɪn': ['k'],
#  'kɒˈʃʊʃkoʊ': ['k'],
#  'kəbĕl': ['k', '##ə', '##b'],
#  'kədo̅o̅': ['k', '##ə', '##do'],
#  'kəlĭg': ['k', '##ə', '##l'],
#  'kərəmʨən̪d̪': ['k', '##ə', '##r', '##ə', '##m'],
#  'kətĭng': ['k', '##ə', '##t'],
#  'kəɾəmʧən̪d̪': ['k', '##ə', '##ɾ', '##ə', '##m'],
#  'kəˈlaɪdəˌskəʊp': ['k', '##ə', '##ˈ', '##la', '##ɪ', '##d', '##ə'],
#  'kəˈlɒdʒ': ['k', '##ə', '##ˈ', '##l'],
#  'kəˈprɒfədʒiː': ['k', '##ə', '##ˈ', '##p', '##r'],
#  'kəˈsɪtəˌraɪt': ['k', '##ə', '##ˈ', '##s', '##ɪ', '##t', '##ə'],
#  'kə̇n': ['k', '##ə'],
#  'kɜrɡɪˈstɑːn': ['k'],
#  'kʰɯːlˠ̪əs̪': ['k', '##ʰ'],
#  'kӕstəˈnets': ['k'],
#  'kӕt': ['k'],
#  'kỷ': ['k'],
#  'lak´rĭ': ['la', '##k', '##´', '##r'],
#  'lampedusaˌlæm': ['lamp', '##ed', '##usa'],
#  'legitĭmus': ['leg', '##it'],
#  'lensesвЂќ': ['lenses', '##в'],
#  'liˈɒf': ['l', '##i', '##ˈ'],
#  'liˈɒl': ['l', '##i', '##ˈ'],
#  'lookâ¦': ['look', '##â'],
#  'loverｿｽfs': ['lover'],
#  'love♪♫': ['love'],
#  'lo̅o̅': ['lo'],
#  'lo̅o̅s': ['lo'],
#  'lo͞o': ['lo'],
#  'lo͞ord': ['lo'],
#  'l¦ge': ['l'],
#  'lÃ': ['l'],
#  'lÃ¤uft': ['l'],
#  'lÃ¨s': ['l'],
#  'lô´rēĬt': ['l', '##ô', '##´', '##r', '##ē'],
#  'lĕh': ['l'],
#  'lĕl': ['l'],
#  'lĕp': ['l'],
#  'lĕth': ['l'],
#  'lĭ': ['l'],
#  'lĭKH': ['l'],
#  'lĭb': ['l'],
#  'lĭg': ['l'],
#  'lĭgyŏrˈēən': ['l'],
#  'lĭk': ['l'],
#  'lĭks': ['l'],
#  'lĭm': ['l'],
#  'lĭn': ['l'],
#  'lĭnz': ['l'],
#  'lĭpănˈtō': ['l'],
#  'lĭs': ['l'],
#  'lĭst': ['l'],
#  'lĭt': ['l'],
#  'lĭth': ['l'],
#  'lĭts': ['l'],
#  'lĭz': ['l'],
#  'lɒm': ['l'],
#  'lɒn': ['l'],
#  'lɒt': ['l'],
#  'lɒx': ['l'],
#  'ləˈmɒl': ['l', '##ə', '##ˈ', '##m'],
#  'lɪˌsiːz': ['l', '##ɪ'],
#  'lˈɒdʒ': ['l', '##ˈ'],
#  'lˌi': ['l'],
#  'lߐei': ['l'],
#  'lｿｽfOpera': ['l'],
#  'maguŝ': ['ma', '##gu'],
#  'malyĭ': ['ma', '##ly'],
#  'malʹe': ['ma', '##l'],
#  'mal΄ә': ['ma', '##l'],
#  'maniÃ¨re': ['man', '##i'],
#  'man´dĭ': ['man', '##´', '##d'],
#  'martedÃ¬': ['ma', '##rted'],
#  'martinetˌmɑr': ['ma', '##rt', '##inet'],
#  'marǧūmay': ['ma', '##r'],
#  'marǧūmi': ['ma', '##r'],
#  'membranesÃ¢âï': ['membrane', '##s'],
#  'merĝ': ['me', '##r'],
#  'meɦˈrɔːn': ['me'],
#  'millÃ³n': ['mill'],
#  'miraculousâ¦': ['mi', '##rac', '##ulous', '##â'],
#  'mittensâ¦': ['mit', '##tens', '##â'],
#  'miṯqāl': ['mi'],
#  'mores™': ['more', '##s'],
#  'motherâ€™s': ['mother', '##â', '##€'],
#  'move┬áyour┬áshoulder': ['move'],
#  'moɦən̪d̪äs': ['m', '##o'],
#  'moːɦən̪d̪aːs': ['m', '##o', '##ː'],
#  'mo͝or': ['m', '##o'],
#  'mo͝ormänsk': ['m', '##o'],
#  'muchâ¦the': ['much', '##â'],
#  'mušḫuššu': ['m', '##u', '##š'],
#  'my\ue000': ['my'],
#  'mÃ': ['m'],
#  'märˈməlādˌ': ['m', '##ä', '##r', '##ˈ', '##m', '##ə', '##l', '##ā', '##d'],
#  'mǣth': ['m', '##æ'],
#  'māk΄iŋ': ['m', '##ā', '##k'],
#  'mătˈəpănˌ': ['m', '##ă', '##t', '##ˈ', '##ə', '##p', '##ă', '##n'],
#  'mĕd': ['m'],
#  'mĕg': ['m'],
#  'mĕk': ['m'],
#  'mĕn': ['m'],
#  'mĕndəlā': ['m'],
#  'mĕnōrāh': ['m'],
#  'mĕt': ['m'],
#  'mĕth': ['m'],
#  'mĭ': ['m'],
#  'mĭd': ['m'],
#  'mĭdlō': ['m'],
#  'mĭk': ['m'],
#  'mĭl': ['m'],
#  'mĭn': ['m'],
#  'mĭs': ['m'],
#  'mǣd': ['m'],
#  'mɐləjaːɭəm': ['m', '##ɐ', '##l', '##ə', '##ja', '##ː'],
#  'mɑˈɡ̊ʁæːˀd̥ə': ['m', '##ɑ', '##ˈ', '##ɡ'],
#  'mɒleːrt': ['m'],
#  'mɒnd': ['m'],
#  'mɒnəkoʊ': ['m'],
#  'mənĭl': ['m', '##ə', '##n'],
#  'mərlĭng': ['m', '##ə', '##rl'],
#  'məɦaːt̪maː': ['m', '##ə'],
#  'məˈlɒdʒ': ['m', '##ə', '##ˈ', '##l'],
#  'məˌleɪd': ['m', '##ə'],
#  'məˌneɪ': ['m', '##ə'],
#  'mɛlˈpɒmɨniː': ['m', '##ɛ', '##l', '##ˈ', '##p'],
#  'mɜːl': ['m'],
#  'mɪˈsɒdʒ': ['m', '##ɪ', '##ˈ', '##s'],
#  'mɪˌtɔr': ['m', '##ɪ'],
#  'mḗnē': ['m'],
#  'm∙K': ['m'],
#  'naḍhīr': ['na', '##d'],
#  'nanny⎯one': ['na', '##nny'],
#  'narratorâ€™s': ['narrator', '##â', '##€'],
#  'naskiĝas': ['na', '##ski'],
#  'nationâ€™s': ['nation', '##â', '##€'],
#  'nationпїЅs': ['nation', '##п', '##ї'],
#  'naẓara': ['na'],
#  'naẓīr': ['na'],
#  'nepažįstamas': ['ne', '##pa', '##ž'],
#  'net™': ['net'],
#  'net™Smaug': ['net'],
#  'net⭐ALL': ['net'],
#  'ngỗng': ['ng'],
#  'ningÃºn': ['ni', '##ng'],
#  'niˌi': ['ni'],
#  'niˌoʊ': ['ni'],
#  'niˌɑ': ['ni'],
#  'nom´ĕ': ['no', '##m', '##´'],
#  'now😉': ['now'],
#  'no͞o': ['no'],
#  'no͞os': ['no'],
#  'nyo͝o': ['n', '##yo'],
#  'nyo͞o': ['n', '##yo'],
#  'nyĭ': ['n', '##y'],
#  'nyĭk': ['n', '##y'],
#  'nyĭvä': ['n', '##y'],
#  'nÃ©e': ['n'],
#  'nÅtÃ': ['n', '##Å', '##t'],
#  'nâ€¦': ['n', '##â', '##€'],
#  'närˈthĕks': ['n', '##ä', '##r', '##ˈ', '##th'],
#  'nôˌvĪə': ['n', '##ô'],
#  'nēmŏsˈĭnē': ['n', '##ē', '##m', '##ŏ', '##s', '##ˈ'],
#  'nĕ': ['n'],
#  'nĕf': ['n'],
#  'nĕk': ['n'],
#  'nĕm': ['n'],
#  'nĕn': ['n'],
#  'nĕnz': ['n'],
#  'nĕr': ['n'],
#  'nĕs': ['n'],
#  'nĕt': ['n'],
#  'nĕth': ['n'],
#  'nĭb': ['n'],
#  'nĭk': ['n'],
#  'nĭkō': ['n'],
#  'nĭm': ['n'],
#  'nĭn': ['n'],
#  'nĭng': ['n'],
#  'nĭnˈəvə': ['n'],
#  'nĭs': ['n'],
#  'nĭz': ['n'],
#  'nŭdyĕˈzhdə': ['n', '##ŭ', '##dy'],
#  'nɐsiˈmẽtu': ['n', '##ɐ', '##si', '##ˈ', '##m'],
#  'nɒʃ': ['n'],
#  'nəˈmɒnɨk': ['n', '##ə', '##ˈ', '##m'],
#  'nəˈstɜr': ['n', '##ə', '##ˈ', '##st'],
#  'nəˈstɜːʃəm': ['n', '##ə', '##ˈ', '##st'],
#  'nəˈθɒl': ['n', '##ə', '##ˈ', '##θ'],
#  'nəˌfaɪdz': ['n', '##ə'],
#  'nəˌvɔr': ['n', '##ə'],
#  'nəˌvɪk': ['n', '##ə'],
#  'nɜrˈvoʊ': ['n'],
#  'nɪˌiː': ['n', '##ɪ'],
#  'nʕm': ['n'],
#  'nˌbɜr': ['n'],
#  'n̪ˠə': ['n'],
#  'nṯ̣r': ['n'],
#  'n™sir': ['n'],
#  'of┬áthe': ['of'],
#  'omniprÃ¤sent': ['o', '##m', '##ni', '##p', '##r'],
#  'oneâ€™s': ['one', '##â', '##€'],
#  'operaｿｽfs': ['opera'],
#  'operaｿｽh': ['opera'],
#  'or̄kh': ['or'],
#  'otherｿｽfs': ['other'],
#  'out΄': ['out'],
#  'oōzˌdā': ['o', '##ō', '##z'],
#  'oʊˈnaɪroʊˌmænsi': ['o', '##ʊ', '##ˈ', '##na', '##ɪ', '##ro', '##ʊ'],
#  'oˈneiroˌmancer': ['o', '##ˈ', '##ne', '##iro'],
#  'o̞u': ['o'],
#  'o͝olēvā': ['o'],
#  'o͞o': ['o'],
#  'o͞od': ['o'],
#  'o͞oz': ['o'],
#  'oﬀ': ['o'],
#  'oﬀense': ['o'],
#  'oﬃcers': ['o'],
#  'oﬃces': ['o'],
#  'oﬃcials': ['o'],
#  'palm™': ['palm'],
#  'pantekˈnikänˌ': ['pan', '##te', '##k', '##ˈ', '##nik', '##ä', '##n'],
#  'party™': ['party'],
#  'parſnips': ['par'],
#  'passedâ¦': ['passed', '##â'],
#  'paĝo': ['p', '##a'],
#  'paʹper': ['p', '##a'],
#  'penjátʹ': ['pen', '##j', '##á', '##t'],
#  'pentēkostḗ': ['pen', '##t', '##ē', '##kos', '##t'],
#  'penˈtӕθlən': ['pen', '##ˈ', '##t'],
#  'perchÃ©': ['perch'],
#  'perestroikaˌpɛr': ['per', '##est', '##roi', '##ka'],
#  'perestroĭka': ['per', '##est', '##ro'],
#  'perestróĭka': ['per', '##est', '##r', '##ó'],
#  'perfectâ¦': ['perfect', '##â'],
#  'personвЂ™s': ['person', '##в'],
#  'perÃ²': ['per'],
#  'pe̞ˈlɛ': ['p', '##e'],
#  'pe̱tri': ['p', '##e'],
#  'phở': ['p', '##h'],
#  'pietaˌpi': ['pie', '##ta'],
#  'pisˈikulˌchər': ['p', '##is', '##ˈ', '##ik', '##ul'],
#  'pleaſant': ['plea'],
#  'plectĕre': ['p', '##lect'],
#  'plo̵̅o̅': ['p', '##lo'],
#  'plo͞o': ['p', '##lo'],
#  'plumeˌnɒm': ['p', '##lume'],
#  'plĕʹthərə': ['p', '##l'],
#  'plĭthôʹrə': ['p', '##l'],
#  'plɒt': ['p', '##l'],
#  'plɪˈθɔːɹə': ['p', '##l', '##ɪ', '##ˈ', '##θ', '##ɔ', '##ː'],
#  'pointâ¦': ['point', '##â'],
#  'polydipsiaˌpɒl': ['p', '##oly', '##di', '##ps', '##ia'],
#  'polynĭi': ['p', '##oly', '##n'],
#  'polyĭ': ['p', '##oly'],
#  'po͝o': ['p', '##o'],
#  'pptпїЅ': ['pp', '##t', '##п', '##ї'],
#  'prōtotokos': ['pro'],
#  'prȳde': ['p', '##ry'],
#  'prȳthi': ['p', '##ry'],
#  'prÃ©sence': ['p', '##r'],
#  'prĕ': ['p', '##r'],
#  'prĕs': ['p', '##r'],
#  'prĕt': ['p', '##r'],
#  'prĕven': ['p', '##r'],
#  'prĭn': ['p', '##r'],
#  'prɒsˈθɛt': ['p', '##r'],
#  'prϑni': ['p', '##r'],
#  'pterodactylˌtɛr': ['p', '##tero', '##da', '##ct', '##yl'],
#  'publikÃ': ['pub', '##lik'],
#  'puÃ²': ['pu'],
#  'pÃ¨re': ['p'],
#  'pâ¦': ['p', '##â'],
#  'pæliɒntɒlədʒi': ['p', '##æ', '##li'],
#  'pænˈtɛknɪˌkɑn': ['p', '##æ', '##n', '##ˈ', '##t', '##ɛ', '##k', '##n', '##ɪ'],
#  'pāʹpər': ['p', '##ā'],
#  'pĕ': ['p'],
#  'pĕd': ['p'],
#  'pĕg': ['p'],
#  'pĕk': ['p'],
#  'pĕl': ['p'],
#  'pĕn': ['p'],
#  'pĕnt': ['p'],
#  'pĕr': ['p'],
#  'pĕrdü': ['p'],
#  'pĕt': ['p'],
#  'pĭ': ['p'],
#  'pĭch': ['p'],
#  'pĭgmāl': ['p'],
#  'pĭgmālˈyən': ['p'],
#  'pĭk': ['p'],
#  'pĭl': ['p'],
#  'pĭn': ['p'],
#  'pĭng': ['p'],
#  'pĭns': ['p'],
#  'pĭprĭ': ['p'],
#  'pĭprŭ': ['p'],
#  'pĭs': ['p'],
#  'pōrĭf': ['p', '##ō', '##r'],
#  'pȁpar': ['p'],
#  'pȯint': ['p'],
#  'pɒp': ['p'],
#  'pərˌsænd': ['p', '##ə', '##r'],
#  'pəˈlɜr': ['p', '##ə', '##ˈ', '##l'],
#  'pəˈnɒl': ['p', '##ə', '##ˈ', '##n'],
#  'pəˌlɛm': ['p', '##ə'],
#  'pəˌpɪl': ['p', '##ə'],
#  'pəˌrɒt': ['p', '##ə'],
#  'pəˌsiz': ['p', '##ə'],
#  'pɜːθ': ['p'],
#  'pɹiːˈdjəː': ['p'],
#  'pӕndiˈmouniəm': ['p'],
#  'queÃ±oas': ['que'],
#  'qɯrʁɯsˈstɑn': ['q'],
#  'ray™': ['ray'],
#  'rdÃ': ['r', '##d'],
#  'realizarÃ': ['real', '##iza', '##r'],
#  'reasoningâ€™': ['reasoning', '##â', '##€'],
#  'res΄ə': ['re', '##s'],
#  'retÃ©': ['re', '##t'],
#  'reˈzɒː': ['re', '##ˈ', '##z'],
#  'rhȳtḗ': ['r', '##h'],
#  'rik´әts': ['r', '##ik', '##´'],
#  'robbers\uf0b7': ['r', '##ob', '##bers'],
#  'rotґid': ['rot'],
#  'ro̅o̅': ['r', '##o'],
#  'ro͞o': ['r', '##o'],
#  'ro͞ok': ['r', '##o'],
#  'rtÃ©netÃ©nek': ['r', '##t'],
#  'rtÃ©nÃ©sz': ['r', '##t'],
#  'rublʹ': ['rub', '##l'],
#  'rÃ': ['r'],
#  'räo̅olˈ': ['r', '##ä', '##o'],
#  'rēzґ': ['r', '##ē', '##z'],
#  'rēĕl': ['r', '##ē'],
#  'rĕd': ['r'],
#  'rĕk': ['r'],
#  'rĕl': ['r'],
#  'rĕn': ['r'],
#  'rĕs': ['r'],
#  'rĕv': ['r'],
#  'rĕz': ['r'],
#  'rīˑ': ['r', '##ī'],
#  'rĭ': ['r'],
#  'rĭg': ['r'],
#  'rĭk': ['r'],
#  'rĭkh': ['r'],
#  'rĭkhˈärt': ['r'],
#  'rĭks': ['r'],
#  'rĭn': ['r'],
#  'rĭpī': ['r'],
#  'rĭt': ['r'],
#  'rȳman': ['r'],
#  'rəgräf΄': ['r', '##ə', '##g', '##r', '##ä', '##f'],
#  'rəˈstɒl': ['r', '##ə', '##ˈ', '##st'],
#  'rəˌmæn': ['r', '##ə'],
#  'rɪˈɡɜː': ['r', '##ɪ', '##ˈ', '##ɡ'],
#  'rɪˌtɑs': ['r', '##ɪ'],
#  'rˤuʔ': ['r'],
#  'r̥tko': ['r'],
#  'r̴iː': ['r'],
#  'rӯman': ['r'],
#  'sautÃ©ed': ['sa', '##ut'],
#  'sautÃ©ing': ['sa', '##ut'],
#  'sautĂŠed': ['sa', '##ut'],
#  'saɕimiꜜ': ['sa', '##ɕ', '##im', '##i'],
#  'saɪzˈmɒl': ['sa', '##ɪ', '##z', '##ˈ', '##m'],
#  'school\uf0b7': ['school'],
#  'secretпїЅso': ['secret', '##п', '##ї'],
#  'secret⎯that': ['secret'],
#  'seguirÃ': ['se', '##gu', '##ir'],
#  'seguÃ¬': ['se', '##gu'],
#  'seismoloģija': ['se', '##ism', '##olo'],
#  'seismoloģisks': ['se', '##ism', '##olo'],
#  'serÃan': ['se', '##r'],
#  'sesiÃ³n': ['se', '##si'],
#  'seˈβiʎa': ['se', '##ˈ', '##β', '##i'],
#  'seˈβiʝa': ['se', '##ˈ', '##β', '##i'],
#  'sfĭg': ['s', '##f'],
#  'sfĭngks': ['s', '##f'],
#  'shapâ¦': ['s', '##ha', '##p', '##â'],
#  'shoĭ': ['s', '##ho'],
#  'sho͞o': ['s', '##ho'],
#  'shĕl': ['s', '##h'],
#  'shĕlz': ['s', '##h'],
#  'shĕt': ['s', '##h'],
#  'shĭk': ['s', '##h'],
#  'shĭr': ['s', '##h'],
#  'shədo͝of': ['s', '##h', '##ə', '##do'],
#  'siphпїЅnariпїЅs': ['sip', '##h', '##п', '##ї'],
#  'siphпїЅnпїЅphпїЅrпїЅs': ['sip', '##h', '##п', '##ї'],
#  'sivilingeniÃ¸r': ['si', '##vili', '##nge', '##ni'],
#  'siÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¨cle': ['si'],
#  'siʔaɫ': ['si', '##ʔ', '##a'],
#  'skjÃ³r': ['s', '##k', '##j'],
#  'skrĭt': ['s', '##k', '##r'],
#  'skănˌdĭnāˈvēə': ['s', '##k', '##ă', '##n'],
#  'slyd̥a': ['sly', '##d'],
#  'smd\ue000': ['s', '##m', '##d'],
#  'songпїЅs': ['song', '##п', '##ї'],
#  'so͞o': ['so'],
#  'spek΄trō': ['s', '##pe', '##k'],
#  'spiґro': ['s', '##pi'],
#  'splḗn': ['s', '##p', '##l'],
#  'spo͝ot': ['s', '##po'],
#  'spo͞ot': ['s', '##po'],
#  'spēˌlēälˈəjē': ['s', '##p', '##ē'],
#  'spɒnˈdjuːlɪks': ['s', '##p'],
#  'srednyeĭ': ['s', '##red', '##ny', '##e'],
#  'stakˑ': ['s', '##ta', '##k'],
#  'stateпїЅs': ['state', '##п', '##ї'],
#  'staʹpēz': ['s', '##ta'],
#  'strojĭ': ['s', '##tro', '##j'],
#  'stroĭka': ['s', '##tro'],
#  'strǣt': ['s', '##tr'],
#  'stȳlí̄tēs': ['s', '##ty'],
#  'stĕn': ['s', '##t'],
#  'stĕr': ['s', '##t'],
#  'stĕt': ['s', '##t'],
#  'stȳlitēs': ['s', '##t'],
#  'subtletyâ¦': ['subtle', '##ty', '##â'],
#  'suk΄ər': ['su', '##k'],
#  'sunnǭ': ['sun', '##n'],
#  'sureâ¦â': ['sure', '##â'],
#  'sweatyarmpiâ¦': ['sweaty', '##arm', '##pi', '##â'],
#  'swĭnt': ['s', '##w'],
#  'systemοΏ½s': ['system', '##ο'],
#  'syĭ': ['s', '##y'],
#  'szÃ©premÃ©nyÅ±': ['s', '##z'],
#  's¸g': ['s'],
#  'sÃ¬': ['s'],
#  'sÃ³lo': ['s'],
#  'sã˙nyôr': ['s', '##ã'],
#  'säNtĕrˈ': ['s', '##ä', '##N', '##t'],
#  'sāˈpēenzˌ': ['s', '##ā', '##ˈ', '##p', '##ē', '##en', '##z'],
#  'sā˙j': ['s', '##ā'],
#  'sĕj': ['s'],
#  'sĕk': ['s'],
#  'sĕm': ['s'],
#  'sĕn': ['s'],
#  'sĕp': ['s'],
#  'sĕv': ['s'],
#  'sĭ': ['s'],
# ...
#  '斗': [],
#  '料': [],
#  '斯': [],
#  '旅': [],
#  '族': [],
#  '早': [],
#  '旭': [],
#  '时': [],
#  '昂': [],
#  '昆': [],
#  '昇': [],
#  '昊': [],
#  '易': [],
#  '映': [],
#  '春': [],
#  '昭': [],
#  '是': [],
#  '時': [],
#  '晃': [],
#  '晋': [],
#  '晓': [],
#  '景': [],
#  '晶': [],
#  '智': [],
#  '暁': [],
#  '暗': [],
#  '暫': [],
#  '曉': [],
#  '曙': [],
#  '曲': [],
#  '更': [],
#  '曹': [],
#  '曺': [],
#  '曽': [],
#  '替': [],
#  '最': [],
#  '會': [],
#  '有': [],
#  '朗': [],
#  '望': [],
#  '朝': [],
#  '期': [],
#  '未': [],
#  '朱': [],
#  '朴': [],
#  '机': [],
#  '杉': [],
#  '杏': [],
#  '杜': [],
#  '条': [],
#  '来': [],
#  '杯': [],
#  '板': [],
#  '极': [],
#  '枢': [],
#  '柏': [],
#  '柔': [],
#  '柳': [],
#  '柴': [],
#  '栄': [],
#  '栈': [],
#  '栋': [],
#  '栖': [],
#  '校': [],
#  '株': [],
#  '根': [],
#  '栽': [],
#  '桂': [],
#  '桐': [],
#  '桜': [],
#  '桥': [],
#  '梁': [],
#  '梅': [],
#  '條': [],
#  '梦': [],
#  '梨': [],
#  '梶': [],
#  '棚': [],
#  '棟': [],
#  '森': [],
#  '植': [],
#  '楠': [],
#  '業': [],
#  '楽': [],
#  '榜': [],
#  '榮': [],
#  '構': [],
#  '様': [],
#  '槿': [],
#  '樂': [],
#  '樓': [],
#  '権': [],
#  '横': [],
#  '樹': [],
#  '橋': [],
#  '機': [],
#  '櫻': [],
#  '次': [],
#  '欣': [],
#  '歌': [],
#  '歐': [],
#  '止': [],
#  '死': [],
#  '歼': [],
#  '残': [],
#  '殺': [],
#  '殿': [],
#  '毒': [],
#  '比': [],
#  '民': [],
#  '気': [],
#  '永': [],
#  '汁': [],
#  '汉': [],
#  '汤': [],
#  '汶': [],
#  '決': [],
#  '沈': [],
#  '沒': [],
#  '沖': [],
#  '沙': [],
#  '油': [],
#  '治': [],
#  '沼': [],
#  '沽': [],
#  '況': [],
#  '泉': [],
#  '法': [],
#  '波': [],
#  '泰': [],
#  '洋': [],
#  '津': [],
#  '洩': [],
#  '洪': [],
#  '洲': [],
#  '活': [],
#  '派': [],
#  '流': [],
#  '浅': [],
#  '济': [],
#  '浙': [],
#  '浜': [],
#  '浦': [],
#  '浩': [],
#  '浪': [],
#  '涙': [],
#  '淇': [],
#  '深': [],
#  '淳': [],
#  '淵': [],
#  '淸': [],
#  '淺': [],
#  '清': [],
#  '済': [],
#  '渋': [],
#  '渚': [],
#  '渡': [],
#  '港': [],
#  '游': [],
#  '湖': [],
#  '湯': [],
#  '源': [],
#  '滋': [],
#  '滕': [],
#  '滙': [],
#  '漂': [],
#  '演': [],
#  '漢': [],
#  '漫': [],
#  '潔': [],
#  '潤': [],
#  '潮': [],
#  '澤': [],
#  '澳': [],
#  '濃': [],
#  '瀬': [],
#  '灣': [],
#  '火': [],
#  '灵': [],
#  '災': [],
#  '灿': [],
#  '炎': [],
#  '炮': [],
#  '烈': [],
#  '焔': [],
#  '然': [],
#  '焼': [],
#  '煙': [],
#  '照': [],
#  '燃': [],
#  '燊': [],
#  '燕': [],
#  '燦': [],
#  '爆': [],
#  '爭': [],
#  '爱': [],
#  '爾': [],
#  '片': [],
#  '牙': [],
#  '牛': [],
#  '牡': [],
#  '物': [],
#  '特': [],
#  '犯': [],
#  '狂': [],
#  '狩': [],
#  '独': [],
#  '狮': [],
#  '狼': [],
#  '猫': [],
#  '猴': [],
#  '獄': [],
#  '獎': [],
#  '獣': [],
#  '獨': [],
#  '玄': [],
#  '玉': [],
#  '环': [],
#  '珊': [],
#  '珠': [],
#  '珩': [],
#  '珪': [],
#  '現': [],
#  '球': [],
#  '理': [],
#  '琉': [],
#  '琢': [],
#  '琪': [],
#  '琳': [],
#  '瑞': [],
#  '瑤': [],
#  '瑶': [],
#  '環': [],
#  '瓜': [],
#  '甄': [],
#  '産': [],
#  '用': [],
#  '由': [],
#  '甲': [],
#  '申': [],
#  '电': [],
#  '男': [],
#  '町': [],
#  '画': [],
#  '界': [],
#  '畑': [],
#  '留': [],
#  '畝': [],
#  '略': [],
#  '異': [],
#  '病': [],
#  '発': [],
#  '登': [],
#  '百': [],
#  '的': [],
#  '盛': [],
#  '盟': [],
#  '盤': [],
#  '目': [],
#  '直': [],
#  '相': [],
#  '看': [],
#  '県': [],
#  '眠': [],
#  '睦': [],
#  '瞬': [],
#  '矢': [],
#  '知': [],
#  '砂': [],
#  '研': [],
#  '砲': [],
#  '破': [],
#  '硫': [],
#  '碑': [],
#  '磨': [],
#  '示': [],
#  '礼': [],
#  '祉': [],
#  '祐': [],
#  '祖': [],
#  '祝': [],
#  '祥': [],
#  '祭': [],
#  '福': [],
#  '秀': [],
#  '秋': [],
#  '科': [],
#  '秦': [],
#  '稔': [],
#  '稲': [],
#  '穂': [],
#  '積': [],
#  '穎': [],
#  '空': [],
#  '突': [],
#  '窗': [],
#  '立': [],
#  '站': [],
#  '竜': [],
#  '章': [],
#  '童': [],
#  '端': [],
#  '競': [],
#  '笑': [],
#  '笠': [],
#  '第': [],
#  '等': [],
#  '筋': [],
#  '筠': [],
#  '算': [],
#  '箭': [],
#  '箱': [],
#  '節': [],
#  '範': [],
#  '篠': [],
#  '篤': [],
#  '米': [],
#  '粘': [],
#  '粵': [],
#  '精': [],
#  '糎': [],
#  '糕': [],
#  '糖': [],
#  '紀': [],
#  '紅': [],
#  '紋': [],
#  '納': [],
#  '純': [],
#  '紘': [],
#  '紙': [],
#  '級': [],
#  '素': [],
#  '細': [],
#  '紳': [],
#  '紹': [],
#  '組': [],
#  '経': [],
#  '結': [],
#  '絕': [],
#  '絵': [],
#  '經': [],
#  '維': [],
#  '綾': [],
#  '綿': [],
#  '緒': [],
#  '線': [],
#  '編': [],
#  '縄': [],
#  '織': [],
#  '繡': [],
#  '红': [],
#  '纳': [],
#  '经': [],
#  '绣': [],
#  '绿': [],
#  '罗': [],
#  '羅': [],
#  '羽': [],
#  '翁': [],
#  '翔': [],
#  '翠': [],
#  '翡': [],
#  '者': [],
#  '耐': [],
#  '耳': [],
#  '联': [],
#  '聖': [],
#  '聞': [],
#  '聡': [],
#  '聯': [],
#  '肉': [],
#  '股': [],
#  '育': [],
#  '胡': [],
#  '能': [],
#  '脳': [],
#  '腐': [],
#  '腹': [],
#  '臣': [],
#  '臨': [],
#  '自': [],
#  '至': [],
#  '致': [],
#  '興': [],
#  '舞': [],
#  '航': [],
#  '船': [],
#  '艦': [],
#  '良': [],
#  '色': [],
#  '艾': [],
#  '节': [],
#  '芙': [],
#  '芝': [],
#  '芳': [],
#  '芸': [],
#  '苏': [],
#  '苔': [],
#  '苦': [],
#  '英': [],
#  '茂': [],
#  '茉': [],
#  '茜': [],
#  '茵': [],
#  '茶': [],
#  '草': [],
#  '荒': [],
#  '荘': [],
#  '荷': [],
#  '莉': [],
#  '莊': [],
#  '莎': [],
#  '莫': [],
#  '菊': [],
#  '菓': [],
#  '菜': [],
#  '菠': [],
#  '華': [],
#  '菱': [],
#  '葉': [],
#  '葛': [],
#  '董': [],
#  '蒯': [],
#  '蒼': [],
#  '蓝': [],
#  '蓮': [],
#  '蔡': [],
#  '蔵': [],
#  '薙': [],
#  '薛': [],
#  '藍': [],
#  '藝': [],
#  '藥': [],
#  '蘇': [],
#  '蘭': [],
#  '蘿': [],
#  '虎': [],
#  '虐': [],
#  '虜': [],
#  '號': [],
#  '虫': [],
#  '蛇': [],
#  '蛉': [],
#  '蛋': [],
#  '蛛': [],
#  '蜓': [],
#  '蜘': [],
#  '蜜': [],
#  '蜻': [],
#  '蟲': [],
#  '血': [],
#  '行': [],
#  '術': [],
#  '衛': [],
#  '衣': [],
#  '表': [],
#  '袁': [],
#  '袋': [],
#  '裁': [],
#  '裂': [],
#  '裏': [],
#  '裕': [],
#  '裝': [],
#  '裡': [],
#  '裴': [],
#  '裸': [],
#  '製': [],
#  '襲': [],
#  '覇': [],
#  '見': [],
#  '視': [],
#  '親': [],
#  '覺': [],
#  '视': [],
#  '角': [],
#  '解': [],
#  '言': [],
#  '計': [],
#  '記': [],
#  '訪': [],
#  '話': [],
#  '誅': [],
#  '誕': [],
#  '語': [],
#  '誠': [],
#  '諏': [],
#  '諭': [],
#  '諸': [],
#  '諾': [],
#  '謙': [],
#  '講': [],
#  '謝': [],
#  '議': [],
#  '譲': [],
#  '護': [],
#  '记': [],
#  '话': [],
#  '语': [],
#  '读': [],
#  '豆': [],
#  '豊': [],
#  '豪': [],
#  '貞': [],
#  '財': [],
#  '貨': [],
#  '貴': [],
#  '賀': [],
#  '賞': [],
#  '賢': [],
#  '贇': [],
#  '贝': [],
#  '财': [],
#  '货': [],
#  '购': [],
#  '赛': [],
#  '赢': [],
#  '赤': [],
#  '赵': [],
#  '起': [],
#  '越': [],
#  '趙': [],
#  '足': [],
#  '路': [],
#  '踏': [],
#  '蹴': [],
#  '軍': [],
#  '転': [],
#  '軸': [],
#  '載': [],
#  '輔': [],
#  '輪': [],
#  '輸': [],
#  '车': [],
#  '轮': [],
#  '轿': [],
#  '辰': [],
#  '農': [],
#  '边': [],
#  '辺': [],
#  '辻': [],
#  '运': [],
#  '近': [],
#  '返': [],
#  '迫': [],
#  '迷': [],
#  '送': [],
#  '逃': [],
#  '逆': [],
#  '通': [],
#  '速': [],
#  '造': [],
#  '連': [],
#  '週': [],
#  '進': [],
#  '逸': [],
#  '遊': [],
#  '運': [],
#  '過': [],
#  '達': [],
#  '遠': [],
#  '選': [],
#  '遺': [],
#  '邇': [],
#  '邉': [],
#  '邓': [],
#  '那': [],
#  '邦': [],
#  '郑': [],
#  '郷': [],
#  '都': [],
#  '郿': [],
#  '鄧': [],
#  '鄭': [],
#  '酒': [],
#  '酷': [],
#  '里': [],
#  '重': [],
#  '釘': [],
#  '鈴': [],
#  '鉄': [],
#  '銀': [],
#  '銃': [],
#  '銑': [],
#  '鋼': [],
#  '錦': [],
#  '錫': [],
#  '錬': [],
#  '録': [],
#  '鍵': [],
#  '鍾': [],
#  '鎬': [],
#  '鎭': [],
#  '鎮': [],
#  '鐘': [],
#  '鐵': [],
#  '锦': [],
#  '開': [],
#  '間': [],
#  '関': [],
#  '閣': [],
#  '闇': [],
#  '闊': [],
#  '闘': [],
#  '门': [],
#  '阪': [],
#  '阮': [],
#  '阵': [],
#  '阿': [],
#  '际': [],
#  '陈': [],
#  '限': [],
#  '院': [],
#  '险': [],
#  '陳': [],
#  '陶': [],
#  '陸': [],
#  '険': [],
#  '隆': [],
#  '隊': [],
#  '階': [],
#  '際': [],
#  '隠': [],
#  '雄': [],
#  '雅': [],
#  '集': [],
#  '雞': [],
#  '難': [],
#  '雪': [],
#  '雲': [],
#  '零': [],
#  '電': [],
#  '震': [],
#  '霊': [],
#  '霧': [],
#  '露': [],
#  '非': [],
#  '面': [],
#  '靴': [],
#  '韓': [],
#  '音': [],
#  '頂': [],
#  '頃': [],
#  '順': [],
#  '須': [],
#  '頌': [],
#  '頭': [],
#  '顧': [],
#  '顶': [],
#  '顿': [],
#  '風': [],
#  '风': [],
#  '飛': [],
#  '飽': [],
#  '飾': [],
#  '館': [],
#  '饮': [],
#  '首': [],
#  '香': [],
#  '馨': [],
#  '馮': [],
#  '馳': [],
#  '駅': [],
#  '駒': [],
#  '駿': [],
#  '騎': [],
#  '騏': [],
#  '騒': [],
#  '驅': [],
#  '驕': [],
#  '骨': [],
#  '體': [],
#  '鬪': [],
#  '鬯': [],
#  '鬼': [],
#  '魂': [],
#  '魔': [],
#  '鮨': [],
#  '鰐': [],
#  '鱲': [],
#  '鲁': [],
#  '鳥': [],
#  '鳳': [],
#  '鴉': [],
#  '鴻': [],
#  '鵬': [],
#  '鶴': [],
#  '鹏': [],
#  '鹿': [],
#  '麗': [],
#  '麥': [],
#  '麵': [],
#  '麻': [],
#  '黃': [],
#  '黄': [],
#  '黎': [],
#  '黑': [],
#  '黒': [],
#  '黙': [],
#  '齡': [],
#  '龙': [],
#  'ꠍꠤꠟꠐꠤ': [],
#  'ꦩꦸꦲꦩ꧀ꦩꦢ꧀ꦯꦸꦲꦂꦠ': [],
#  '각하': [],
#  '감싸안으며': [],
#  '강남스타일': [],
#  '강대수': [],
#  '강성훈': [],
#  '강원도립대학': [],
#  '강혜정': [],
#  '강화': [],
#  '개': [],
#  '거짓말': [],
#  '거짓말을': [],
#  '견뎌라': [],
#  '고려': [],
#  '고품격': [],
#  '골든이글': [],
#  '공부하는': [],
#  '관계': [],
#  '국가대표팀': [],
#  '권보아': [],
#  '권혁': [],
#  '귀요미': [],
#  '귀향': [],
#  '그': [],
#  '그녀': [],
#  '그녀는': [],
#  '그대': [],
#  '그룹': [],
#  '기아자동차': [],
#  '김과장': [],
#  '김동준': [],
#  '김병만의': [],
#  '김성원': [],
#  '김성주': [],
#  '김아일': [],
#  '김어준': [],
#  '김용진': [],
#  '김일성': [],
#  '김재중': [],
#  '김정남': [],
#  '김정은': [],
#  '김정일': [],
#  '김종국': [],
#  '김지연': [],
#  '김지원': [],
#  '김한솔': [],
#  '김현희': [],
#  '꼼수다': [],
#  '나': [],
#  '나꼼수': [],
#  '나는': [],
#  '나만': [],
#  '나비': [],
#  '나탈리': [],
#  '날': [],
#  '너무': [],
#  '넥슨': [],
#  '노회찬': [],
#  '녹색': [],
#  '뉴스공장': [],
#  '뉴이스트': [],
#  '다다': [],
#  '당': [],
#  '당신밖에': [],
#  '대한미식축구협회': [],
#  '대한민국': [],
#  '더': [],
#  '도둑놈': [],
#  '도둑님': [],
#  '동국대학교': [],
#  '동반자살': [],
#  '둠': [],
#  '드럭': [],
#  '드림하이': [],
#  '디워': [],
#  '러브': [],
#  '럭키금성': [],
#  '레드벨벳': [],
#  '레스토랑': [],
#  '레이': [],
#  '로엔': [],
#  '리설주': [],
#  '마녀의': [],
#  '마마무': [],
#  '마산만': [],
#  '마트': [],
#  '말죽거리': [],
#  '맨정신': [],
#  '모노드라마': [],
#  '모란봉체육단': [],
#  '모른다': [],
#  '모해': [],
#  '몬스타엑스': [],
#  '몽골': [],
#  '무': [],
#  '무게를': [],
#  '무도': [],
#  '무신조자룡': [],
#  '문재인': [],
#  '문전본풀이': [],
#  '미쓰에이': [],
#  '미탄면': [],
#  '민윤기': [],
#  '바라봐': [],
#  '바람의': [],
#  '바보': [],
#  '박근혜': [],
#  '박상우': [],
#  '박용택': [],
#  '박재범': [],
#  '박재홍': [],
#  '박쥐': [],
#  '박지민': [],
#  '박지성': [],
#  '박지훈': [],
#  '배기태': [],
#  '배진영': [],
#  '배추': [],
#  '번호': [],
#  '법정': [],
#  '법칙': [],
#  '베일리': [],
#  '벤처': [],
#  '별': [],
#  '병원선': [],
#  '병이에요': [],
#  '보도연맹': [],
#  '보헤미안': [],
#  '복수': [],
#  '부꾸미': [],
#  '부활': [],
#  '불가사리': [],
#  '붐바야': [],
#  '비': [],
#  '비무장': [],
#  '비에이피': [],
#  '빅뱅': [],
#  '빅히트엔터테인먼트': [],
#  '뽕짝': [],
#  '사건': ['사'],
#  '사고': ['사'],
#  '사랑해': ['사'],
#  '삼부작': [],
#  '삼성전자': [],
#  '상속자들': [],
#  '샤이니': [],
#  '서바이벌': [],
#  '서울': [],
#  '서현진': [],
#  '선덕여왕': [],
#  '선데이': [],
#  '설국열차': [],
#  '세븐틴': [],
#  '세월호': [],
#  '소반': [],
#  '소품집': [],
#  '손흥민': [],
#  '송': [],
#  '송민호': [],
#  '수란': [],
#  '슈': [],
#  '슈퍼': [],
#  '슈퍼스타': [],
#  '슈퍼주니어': [],
#  '스타': [],
#  '스튜디오': [],
#  '슬리피': [],
#  '승리': [],
#  '신범철': [],
#  '신세계': [],
#  '신수란': [],
#  '썸머타임': [],
#  '쏘나타': [],
#  '쓰려는': [],
#  '씨엔블루': ['씨'],
#  '아는': [],
#  '아반떼': [],
#  '아이스하키': [],
#  '아이유': [],
#  '아이콘': [],
#  '아카데미쿠스': [],
#  '아케이드': [],
#  '안준희': [],
#  '안희연': [],
#  '애니': [],
#  '애니메이션': [],
#  '양민학살': [],
#  '양수빈': [],
#  '양유찬': [],
#  '어때': [],
#  '언더독': [],
#  '업': [],
#  '에뛰드하우스': [],
#  '에이핑크': [],
#  '에일리': [],
#  '에프엑스': [],
#  '엑소': [],
#  '엔': [],
#  '엔시티': [],
#  '엔터테인먼트': [],
#  '엘란트라': [],
#  '엘에나': [],
#  '여고괴담': [],
#  '여자친구': [],
#  '연상엽': [],
#  '엽기적인': [],
#  '영웅재중': [],
#  '예뻤다': [],
#  '오': [],
#  '오늘': [],
#  '오디션': [],
#  '오피스': [],
#  '올드보이': [],
#  '왕관을': [],
#  '우리는': [],
#  '우주소녀': [],
#  '우지호': [],
#  '원': [],
#  '위너': [],
#  '유규상': [],
#  '유노윤호': [],
#  '유니버설': [],
#  '유밀과': [],
#  '유영진': [],
#  '유키스': [],
#  '음반': [],
#  '의자': ['의'],
#  '이동해': ['이'],
#  '이미나': ['이'],
#  '이미자': ['이'],
#  '이별': ['이'],
#  '이병헌': ['이'],
#  '이삭': ['이'],
#  '이승기': ['이'],
#  '이승현': ['이'],
#  '이야기': ['이'],
#  '이영표': ['이'],
#  '이종석': ['이'],
#  '이종현': ['이'],
#  '이지은': ['이'],
#  '이춘헌': ['이'],
#  '이해민': ['이'],
#  '이호석': ['이'],
#  '인간': [],
#  '인기가요': [],
#  '인피니트': [],
#  '임수정': [],
#  '임윤아': [],
#  '잇': [],
#  '자': [],
#  '자유선언': [],
#  '잔혹사': [],
#  '장우영': [],
#  '장진호': [],
#  '전': [],
#  '전투': [],
#  '정글의': [],
#  '정말': [],
#  '정윤호': [],
#  '정재하야': [],
#  '정재헌': [],
#  '정준영밴드': [],
#  '정진영': [],
#  '정찬성': [],
#  '제네시스': [],
#  '제이제이': [],
#  '젝스키스': [],
#  '조국해방전쟁': [],
#  '조선4': [],
#  '조수미': [],
#  '조양호': [],
#  '좋아': [],
#  '좋은': [],
#  '주식회사': [],
#  '중소기업청': [],
#  '중소벤처기업부': [],
#  '쥬블스': [],
#  '지대': [],
#  '지연': [],
#  '짝사랑': [],
#  '차학연': [],
#  '청해진해운': [],
#  '최강연승': [],
#  '최영의': [],
#  '최재봉': [],
#  '최준홍': [],
#  '침몰': [],
#  '카라': [],
#  '컴보이': [],
#  '케이팝': [],
#  '코리아': [],
#  '퀴즈쇼': [],
#  '크레이지': [],
#  '킹': [],
#  '토요일': [],
#  '투포케이': [],
#  '투피엠': [],
#  '투하트': [],
#  '트러블메이커': [],
#  '트로트': [],
#  '파수꾼': [],
#  '파이터': [],
#  '파파이스': [],
#  '펀치': [],
#  '펌프': [],
#  '평양': [],
#  '포옹': [],
#  '표류': [],
#  '프로젝트': [],
#  '프리스틴': [],
#  '플란다스의': [],
#  '하녀': [],
#  '하이트맥주': [],
#  '하이포': [],
#  '학교': [],
#  '학살사건': [],
#  '한국': ['한'],
#  '한국전쟁': ['한'],
#  '한문': ['한'],
#  '한반도': ['한'],
#  '한아름': ['한'],
#  '한자': ['한'],
#  '해장국': [],
#  '해피': [],
#  '현대': [],
#  '현대백화점': [],
#  '현대자동차': [],
#  '현대자동차그룹': [],
#  '호모': [],
#  '혼자서': [],
#  '황민현': [],
#  '후아유': [],
#  '히트프로젝트': [],
#  '＄キッド': [],
#  '２': [],
#  '３': [],
#  '～': [],
#  '～バイキング～': [],
#  '～ロカビリー': [],
#  '･': [],
#  '𐎤𐎢𐎽𐎢𐏁': [],
#  '𐎧𐏁𐎹𐎠𐎼𐏁𐎠': [],
#  '𐤁𐤓𐤒': [],
#  '𐤂𐤁𐤋': [],
#  '𐤇𐤃𐤔𐤕': [],
#  '𐤇𐤍𐤁𐤏𐤋': [],
#  '𐤊𐤍𐤏𐤍': [],
#  '𐤑𐤅𐤓': [],
#  '𐤒𐤓𐤕': [],
#  '𐤒𐤓𐤕𐤇𐤃𐤔𐤕': [],
#  '𐭩𐭦𐭣𐭪𐭥𐭲𐭩': [],
#  '𒀭': [],
#  '𒀭𒊩𒌆𒆤': [],
#  '𒈥𒌅': [],
#  '𒉢𒁓𒆷𒆠': [],
#  '𒊑𒀀': [],
#  '𒊑𒅀': [],
#  '𓇍𓅓𓊵': [],
#  '𓊪': [],
#  '𓏏': [],
#  '🇦🇷': [],
#  '👍': [],
#  '🔑': [],
#  '𠊛': []}
#
# ./download_out_of_domain_dev/RelationExtraction.jsonl
# {'Avg. answer length': 2.851424694708277,
#  'Avg. context length': 38.02815468113975,
#  'Avg. query length': 11.55156037991859,
#  'Num. context': 2948,
#  'Num. query': 2948,
#  'Num. tokens': 11134}
# Num unique [UNK] : 127
# frequency  [UNK] : 186
# {'Epiphanḗs': ['E', '##pi', '##pha', '##n'],
#  'Tiānshĭ': ['T', '##i', '##ān', '##sh'],
#  'ljuːˈkɒθiə': ['l', '##ju', '##ː', '##ˈ', '##k'],
#  'p̄hạdịthy': ['p'],
#  'teɪˌnɑːrdiˈeɪ': ['te', '##ɪ'],
#  'vɐɫɐnʲˈt͡ʃûːnɐs': ['v', '##ɐ'],
#  'ˈhærᵻboʊ': ['ˈ', '##h', '##æ', '##r'],
#  'ˈmaɪnɒs': ['ˈ', '##ma', '##ɪ', '##n'],
#  'ˈmɒntiːz': ['ˈ', '##m'],
#  'ˈnuːɖɪsk': ['ˈ', '##nu', '##ː'],
#  'ˈt͡ʃɒbɒ': ['ˈ', '##t', '##͡', '##ʃ'],
#  'ˈɦœys': ['ˈ'],
#  'ˌeɪpoʊˈniːn': [],
#  'ˌwiː': [],
#  'ˌʋɪtə': [],
#  'Δ΄': ['Δ'],
#  'Ρακτιβάν': [],
#  'Ђорђевић': [],
#  'Краљевић': ['К', '##р', '##а'],
#  'ҚазСат': [],
#  'Մենուա': [],
#  'Սարդուրի': [],
#  'פָּלֶשְׂתִּינָה': ['פ', '##ָ', '##ּ', '##ל', '##ֶ', '##ש', '##ְ'],
#  'القادسيّة': ['ا', '##ل', '##ق', '##اد', '##س', '##ي'],
#  'جموں': ['ج', '##م', '##و'],
#  'ګل': [],
#  '۲': [],
#  'इश्क': [],
#  'और': [],
#  'खैर': [],
#  'সীতাকুন্ড': ['স', '##ী', '##ত', '##া', '##ক', '##ু', '##ন', '##্'],
#  'হত্যাকান্ড': ['হ', '##ত', '##্', '##য', '##া', '##ক', '##া', '##ন', '##্'],
#  'ചന്ദ്രോത്സവം': [],
#  'ผัดไทย': [],
#  'ጊጋር': [],
#  'ឃិន': [],
#  'សុខ': [],
#  'Ṭurim': [],
#  'Ἀρχίδαμος': [],
#  'Ἐπιφανής': [],
#  'カービィのエアライド': ['カ', '##ー'],
#  '丁': [],
#  '万': [],
#  '业': [],
#  '之': [],
#  '五': [],
#  '份': [],
#  '何': [],
#  '使': [],
#  '侯': [],
#  '倉': [],
#  '创': [],
#  '协': [],
#  '協': [],
#  '县': [],
#  '嘉': [],
#  '奏': [],
#  '如': [],
#  '姬': [],
#  '威': [],
#  '孔': [],
#  '宣': [],
#  '家': [],
#  '察': [],
#  '峰': [],
#  '工': [],
#  '帝': [],
#  '恋': [],
#  '慶': [],
#  '戀': [],
#  '戦': [],
#  '戴': [],
#  '措': [],
#  '政': [],
#  '故': [],
#  '族': [],
#  '旭': [],
#  '是': [],
#  '景': [],
#  '曲': [],
#  '有': [],
#  '柳': [],
#  '桥': [],
#  '業': [],
#  '権': [],
#  '橋': [],
#  '民': [],
#  '流': [],
#  '港': [],
#  '父': [],
#  '瑜': [],
#  '璧': [],
#  '矿': [],
#  '禾': [],
#  '空': [],
#  '縣': [],
#  '續': [],
#  '联': [],
#  '聯': [],
#  '股': [],
#  '航': [],
#  '艺': [],
#  '英': [],
#  '華': [],
#  '萬': [],
#  '蔡': [],
#  '衛': [],
#  '袁': [],
#  '警': [],
#  '鎌': [],
#  '铭': [],
#  '长': [],
#  '限': [],
#  '雀': [],
#  '雄': [],
#  '集': [],
#  '香': [],
#  '黃': [],
#  '黄': [],
#  '간': [],
#  '구자철': [],
#  '까닭은': [],
#  '달마가': [],
#  '대문': [],
#  '동쪽으로': [],
#  '이제하': ['이'],
#  '파란': []}
#
# ./download_out_of_domain_dev/RACE.jsonl.gz
# {'Avg. answer length': 4.250741839762611,
#  'Avg. context length': 380.952691680261,
#  'Avg. query length': 12.396142433234422,
#  'Num. context': 613,
#  'Num. query': 674,
#  'Num. tokens': 14339}
# Num unique [UNK] : 0
# frequency  [UNK] : 0
# {}
#
# ./download_out_of_domain_dev/BioASQ.jsonl.gz
# {'Avg. answer length': 5.429521276595745,
#  'Avg. context length': 353.93949468085106,
#  'Avg. query length': 16.355718085106382,
#  'Num. context': 1504,
#  'Num. query': 1504,
#  'Num. tokens': 10910}
# Num unique [UNK] : 17
# frequency  [UNK] : 27
# {'AUCÏ': ['AU', '##C'],
#  'Engineering™': ['Engineering'],
#  'PrP₂₋₁₀': ['P', '##r', '##P', '##₂'],
#  'P⩽': ['P'],
#  'ℇA': [],
#  '∆ES': [],
#  '∼': [],
#  '∼12': [],
#  '∼15': [],
#  '∼160': [],
#  '∼21': [],
#  '∼30': [],
#  '∼35': [],
#  '∼50': [],
#  '∼76': [],
#  '∼9': [],
#  '∼GD165': []}
#
# ./download_out_of_domain_dev/TextbookQA.jsonl
# {'Avg. answer length': 3.0518962075848304,
#  'Avg. context length': 751.0319361277445,
#  'Avg. query length': 12.092481703260146,
#  'Num. context': 1503,
#  'Num. query': 1503,
#  'Num. tokens': 9716}
# Num unique [UNK] : 0
# frequency  [UNK] : 0
# {}
#
# ./download_out_of_domain_dev/DuoRC.jsonl.gz
# {'Avg. answer length': 2.9060626249167223,
#  'Avg. context length': 798.9207920792079,
#  'Avg. query length': 9.794137241838774,
#  'Num. context': 202,
#  'Num. query': 1501,
#  'Num. tokens': 12958}
# Num unique [UNK] : 23
# frequency  [UNK] : 37
# {'BogotÃ': ['Bo', '##got'],
#  'CiarÃ': ['C', '##iar'],
#  'CÃ©line': ['C'],
#  'JosÃ©': ['Jo', '##s'],
#  'KrabbÃ©': ['K', '##rab', '##b'],
#  'LÃ¤ndler': ['L'],
#  'MordechaÃ¯': ['Mo', '##rde', '##cha'],
#  'MÃ©ishan': ['M'],
#  'MÃ¼ller': ['M'],
#  'SÃ¬': ['S'],
#  'SÃ²ngliÃ': ['S'],
#  'TÃ': ['T'],
#  'TÃ©a': ['T'],
#  'YÃ': ['Y'],
#  'ZhuÃ³yÃºn': ['Zhu'],
#  'cafÃ©': ['ca', '##f'],
#  'fiancÃ©': ['fi', '##an', '##c'],
#  'fiancÃ©e': ['fi', '##an', '##c'],
#  'ingÃ©nue': ['ing'],
#  'naÃ¯ve': ['na'],
#  'naÃ¯vetÃ©': ['na'],
#  'Ãric': [],
#  'Ã©r': []}
#
# ./download_out_of_domain_dev/DROP.jsonl.gz
# {'Avg. answer length': 2.803725881570193,
#  'Avg. context length': 268.4270462633452,
#  'Avg. query length': 11.976713240186294,
#  'Num. context': 281,
#  'Num. query': 1503,
#  'Num. tokens': 8020}
# Num unique [UNK] : 1
# frequency  [UNK] : 1
# {'⅔': []}

# %%
# show unique token of datasets
token_set_dict = dict()
for file in (train_files + out_domain_dev_files) :
    print(file)
    
    common_token_set = set()
    for file2 in (train_files + out_domain_dev_files) :
        if file == file2 : continue
        common_token_set = common_token_set.union(set(list(data[file2][0].keys())))
    
    intersection = set(list(data[file][0].keys())) - common_token_set
    print(list(intersection))
    print(len(intersection), end = "\n\n")
# Out:
# ./download_train/SearchQA.jsonl.gz
# ['Walkover', 'ochreous', 'scooted']
# 3
#
# ./download_train/NewsQA.jsonl.gz
# []
# 0
#
# ./download_train/TriviaQA.jsonl.gz
# ['♦', '##რ', 'ן', 'ს', 'ş', '∩', 'ि', '##ছ', '##∞', 'ो', 'ã', '##ἐ', 'ი', '##ể', '⁹', '##ḳ', '⇒', 'ὰ', 'ỹ', '##ŷ', '##⁵', '##↑', '##⁶', '##ƒ', '●', '##ო', 'ί', '│', '##µ', '##●', '##ʳ', 'ℓ', '∘', '##য়', 'Ľ', 'ğ', 'ा', '##│', '∧', '##ე', 'щ', 'º', '##■', '↔', 'ạ', '##♦', 'ώ', '##І', '##È', '##आ', '##√', '##Е', 'ष', '##ℓ', '͡', 'ئ', '『', 'յ', '##♥', '।', '郡', '##ი', '##そ', '##₅', '##ἀ', '■', '─', '##Ф', 'ţ', '##₃', '³', 'ǫ', '##⁹', 'े', '##¬', '##Μ', 'ო', '亻', 'ु', 'ë', '##₄', '##₆', '##─', '##⁻', '##མ', 'ა', '##₁', 'რ', '##ლ', '##÷', 'ḳ', '##⁸', 'ी', '##ს', '₂', '##≡', '』', '##ⁱ', '##∂', 'ė', '##Γ', 'ŵ', '##☆']
# 103
#
# ./download_train/NaturalQuestions.jsonl.gz
# ['⊂', '##ẩ', 'ལ', '̃', '##À', 'れ', '##ག', '이', '##Ψ', 'ũ', '사', '☉', '́', 'ய', 'ḍ', 'Kaladin', '##Ḥ', 'ッ', '♣', '##ལ', '♠', '##ི', 'ς', '##せ', 'ე', '##Κ', 'ர', 'ར', '##이', 'ư', '॥', 'ー', '⊕', '⊆', '∂', '##ུ']
# 36
#
# ./download_train/SQuAD.jsonl.gz
# ['ь', 'ň', 'ʰ', 'ď', 'ơ', '##≥', 'ы', 'ť', '氵', 'ʲ', 'ń', 'ء']
# 12
#
# ./download_train/HotpotQA.jsonl
# ['##Ј', '##ր', 'կ', 'গ', 'ț', '－', '##մ', '##ར', 'ই', 'ա', '／', 'Sparhawk', '##ո', '##կ', '##Ō', '##Э', '##བ', '##ե', '##Ю', 'ན', '##ḩ', 'ம', '##ւ', 'Crambidae', 'ズ', '##Ч', '##வ']
# 27
#
# ./download_out_of_domain_dev/RelationExtraction.jsonl
# ['##Ś', 'Ḩ']
# 2
#
# ./download_out_of_domain_dev/RACE.jsonl.gz
# []
# 0
#
# ./download_out_of_domain_dev/BioASQ.jsonl.gz
# ['##≤', '##⁺']
# 2
#
# ./download_out_of_domain_dev/TextbookQA.jsonl
# []
# 0
#
# ./download_out_of_domain_dev/DuoRC.jsonl.gz
# []
# 0
#
# ./download_out_of_domain_dev/DROP.jsonl.gz
# []
# 0
